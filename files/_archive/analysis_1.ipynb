# %%
import sqlite3
from sqlite3 import Error
import os.path
from os import path

from create_db import create_connection, create_table, clean_column_names
from populate_db import extract_data, insert_records
import query_db as qd
import config
import build_dataset as build

import importlib
import datetime
import re
import numpy as np
import pandas as pd
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Ridge
from sklearn.model_selection import KFold, cross_val_score, PredefinedSplit
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.metrics import accuracy_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import plot_confusion_matrix, classification_report, plot_roc_curve, plot_precision_recall_curve 

# Decision Tree
from sklearn.tree import DecisionTreeClassifier

from sklearn.model_selection import ParameterGrid
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import ParameterGrid
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
importlib.reload(build)
importlib.reload(config)
# Out:
# <module 'config' from '/Users/daminisharma/Dropbox/Harris MSCAPP/2019-20_Q3_Spring/Machine Learning/covid_decarceration/files/config.py'>

# %%
dataset_1 = pd.read_csv('../data/dataset_main_active1.csv')
#dataset_3 = pd.read_csv('../data/dataset_main_active3.csv')
# Out:
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (21,22,29,30,32) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
dataset_1.head(2)
# Out:
#    ID COMMITMENT_PREFIX EARLIEST_SENTENCE_EFFECTIVE_DT  \
# 0   4                AA                     1983-07-12
# 1   6                AA                     1973-01-30
#
#   MOST_SERIOUS_OFFENSE_CODE INMATE_COMPUTATION_STATUS_FLAG    END_DATE  \
# 0          SELL SCHEDULE II                        EXPIRED  1984-07-11
# 1           WORTHLESS CHECK                        EXPIRED  1973-03-28
#
#   PROJ_END_DATE INMATE_RECORD_STATUS_CODE INMATE_ADMIN_STATUS_CODE  \
# 0    1984-07-11                  INACTIVE                 INACTIVE
# 1    0001-01-01                  INACTIVE                 INACTIVE
#
#   DATE_OF_LAST_INMATE_MOVEMENT  ... Recidivate_Risk_Level Needed a check?_x  \
# 0                   1984-07-11  ...                   0.0               NaN
# 1                   1975-08-18  ...                   1.0                NO
#
#   Recidivate_Risk_Level_Lenient Recidivate_Risk_Level_Harsh  \
# 0                           0.0                         0.0
# 1                           1.0                         1.0
#
#   Primary offense code_y                          Description (if needed)_y  \
# 0       SELL SCHEDULE II  Selling drugs on Schedule II - high potential ...
# 1        WORTHLESS CHECK                                                  0
#
#   Current_Offense_Risk_Level Needed a check?_y  \
# 0                        3.0               YES
# 1                        1.0                NO
#
#   Current_Offense_Risk_Level_Lenient Current_Offense_Risk_Level_Harsh
# 0                                2.0                              4.0
# 1                                1.0                              1.0
#
# [2 rows x 41 columns]

# %%
# BINARY TARGET VAR
grouping_target = config.grouping_target
print(grouping_target)
#print(features)
train_data, test_data, validate_data, active_sentences = build.split_and_process(dataset_1,config,grouping_target)
# Out:
# binary
# 249
# Size of active sentences dataset:  32711
# Dataset size:  778681
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/pandas/core/indexing.py:845: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# /Users/daminisharma/Dropbox/Harris MSCAPP/2019-20_Q3_Spring/Machine Learning/covid_decarceration/files/build_dataset.py:601: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_no_active[target_label] = dataset_no_active['label']
# Total Number of Unique IDs: 419118
# Total Number of IDs in Test Data: 83824
# Total Number of IDs in Train Data: 268235
# Total Number of IDs in Validate Data: 67059
# Do the IDs add up? True
# Does Test Represent 20% of the data? False
# Test Represents X% of the data: 0.20000095438516122
# Does Train+Validate Represent 80% of the data? False
# Train+Validate Represents X% of the data: 0.7999990456148388
# Does Validate Represent 20% of the Train+Validate Data?: 0.20000059649143737
# Does Train Represent 80% of the Train+Validate Data?: 0.7999994035085627
# /Users/daminisharma/Dropbox/Harris MSCAPP/2019-20_Q3_Spring/Machine Learning/covid_decarceration/files/build_dataset.py:686: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   age_first_offense.drop_duplicates(inplace=True)
# Index(['CONTROL_STATUS', 'OFFENSE_CLEAN', 'Current_Offense_Risk_Level',
#        'year_month', 'INFRACTION_PER_SENT', 'misd_count', 'felon_count',
#        'sentence_count', 'age_at_sentence', 'unemp_rate', 'ID',
#        'COMMITMENT_PREFIX', 'BIRTH_DATE', 'EARLIEST_SENTENCE_EFFECTIVE_DT',
#        'INMATE_ADMIN_STATUS_CODE', 'NextPrefix', 'Recidivate_Risk_Level',
#        'age_cat', 'age_first_offense', 'juv_first_offense',
#        'current_crime_violent'],
#       dtype='object')

# %%
# Sanity Check
print('Train and Test Check:')
build.sanity_check(train_data,test_data)

print('Train and Validate Check:')
build.sanity_check(train_data,validate_data)

print('Train and Active Check:')
build.sanity_check(train_data,active_sentences)
# Out:
# Train and Test Check:
# Success: Features match
# Success: No NAs remain
# Train and Validate Check:
# Success: Features match
# Success: No NAs remain
# Train and Active Check:
# Success: Features match

# %%
target = config.target_vars[0]

# %%
validate_data.groupby(target).count()
# Out:
#                        INFRACTION_PER_SENT  misd_count  felon_count  \
# Recidivate_Risk_Level
# 0.0                                 103310      103310       103310
# 1.0                                  21849       21849        21849
#
#                        sentence_count  age_at_sentence  unemp_rate  \
# Recidivate_Risk_Level
# 0.0                            103310           103310      103310
# 1.0                             21849            21849       21849
#
#                        age_first_offense  juv_first_offense  \
# Recidivate_Risk_Level
# 0.0                               103310             103310
# 1.0                                21849              21849
#
#                        current_crime_violent  \
# Recidivate_Risk_Level
# 0.0                                   103310
# 1.0                                    21849
#
#                        CONTROL_STATUS_HIGH SECURITY/MAX CONTROL HCON  ...  \
# Recidivate_Risk_Level                                                 ...
# 0.0                                                           103310  ...
# 1.0                                                            21849  ...
#
#                        age_cat_25-29  age_cat_30-34  age_cat_35-39  \
# Recidivate_Risk_Level
# 0.0                           103310         103310         103310
# 1.0                            21849          21849          21849
#
#                        age_cat_40-44  age_cat_45-49  age_cat_50-54  \
# Recidivate_Risk_Level
# 0.0                           103310         103310         103310
# 1.0                            21849          21849          21849
#
#                        age_cat_55-59  age_cat_60-64  age_cat_65 and older  \
# Recidivate_Risk_Level
# 0.0                           103310         103310                103310
# 1.0                            21849          21849                 21849
#
#                        CONTROL_STATUS_OUT OF CELL RESTRICTION   OUTC
# Recidivate_Risk_Level
# 0.0                                                           103310
# 1.0                                                            21849
#
# [2 rows x 659 columns]

# %%
#21849 / 103310

# %%
#test_data.groupby(target).count()

# %% [markdown]
# # Analysis

# %%
MODELS = config.MODELS
PARAMS = config.PARAMS
model_key = "LogisticRegression"

model = MODELS[model_key]
params = PARAMS[model_key]        



# Include race/gender/ethnicity or exclude?
config.categorical_vars_to_impute
# Out:
# ['CONTROL_STATUS', 'OFFENSE_CLEAN', 'Current_Offense_Risk_Level', 'year_month']

# %%
params
# Out:
# {'penalty': ['l2'], 'C': [10], 'max_iter': [100]}

# %%
target
# Out:
# 'Recidivate_Risk_Level'

# %%
#https://stackoverflow.com/questions/31948879/using-explicit-predefined-validation-set-for-grid-search-with-sklearn
ps = PredefinedSplit(test_fold=validate_data[target])

# %%
#scorer = make_scorer(precision_score, average = None)
#gs_svc = GridSearchCV(estimator=svc_clf,param_grid=param_grid,scoring=scorer,cv=5)

scoring = {'recall': make_scorer(recall_score, average = 'macro'), 'precision': make_scorer(precision_score, average = 'macro'), 'accuracy': make_scorer(accuracy_score)}
grid_model = GridSearchCV(estimator=model, 
                          param_grid=params, 
                          cv=ps,
                          return_train_score=True,
                          scoring=scoring,
                             refit=False,verbose=10)

# %%
grid_model_result = grid_model.fit(train_data.loc[:,train_data.columns!=target],train_data[target])
# Out:
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# [CV] C=10, max_iter=100, penalty=l2 ..................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=10, max_iter=100, penalty=l2, accuracy=(train=0.810, test=0.810), precision=(train=0.690, test=0.655), recall=(train=0.519, test=0.516), total=  24.6s
# [CV] C=10, max_iter=100, penalty=l2 ..................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   26.4s remaining:    0.0s
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [CV]  C=10, max_iter=100, penalty=l2, accuracy=(train=0.811, test=0.809), precision=(train=0.679, test=0.688), recall=(train=0.514, test=0.514), total=  47.2s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  1.4min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  1.4min finished

# %%
cv_results.columns
# Out:
# Index(['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time',
#        'param_C', 'param_max_iter', 'param_penalty', 'params',
#        'split0_test_recall', 'split1_test_recall', 'mean_test_recall',
#        'std_test_recall', 'rank_test_recall', 'split0_train_recall',
#        'split1_train_recall', 'mean_train_recall', 'std_train_recall',
#        'split0_test_precision', 'split1_test_precision', 'mean_test_precision',
#        'std_test_precision', 'rank_test_precision', 'split0_train_precision',
#        'split1_train_precision', 'mean_train_precision', 'std_train_precision',
#        'split0_test_accuracy', 'split1_test_accuracy', 'mean_test_accuracy',
#        'std_test_accuracy', 'rank_test_accuracy', 'split0_train_accuracy',
#        'split1_train_accuracy', 'mean_train_accuracy', 'std_train_accuracy'],
#       dtype='object')

# %%
cv_results = pd.DataFrame(grid_model.cv_results_)


ranked_cv=cv_results.sort_values(by=['rank_test_precision'])
ranked_cv[['param_C','param_max_iter','param_penalty','rank_test_accuracy', 'mean_test_accuracy','mean_test_recall','mean_test_precision']]

ranked_cv['classifier'] = model

ranked_cv

best_params = ranked_cv.iloc[0]['params']

# %%
best_params
# Out:
# {'C': 10, 'max_iter': 100, 'penalty': 'l2'}

# %%
MODELS = config.MODELS
PARAMS = config.PARAMS
model_key = "DecisionTreeClassifier"

model = MODELS[model_key]
params = PARAMS[model_key]        

target = config.target_vars[0]

# Include race/gender/ethnicity or exclude?
config.categorical_vars_to_impute
# Out:
# ['CONTROL_STATUS', 'OFFENSE_CLEAN', 'Current_Offense_Risk_Level', 'year_month']

# %%
#scorer = make_scorer(precision_score, average = None)
#gs_svc = GridSearchCV(estimator=svc_clf,param_grid=param_grid,scoring=scorer,cv=5)

scoring = {'recall': make_scorer(recall_score, average = 'macro'), 'precision': make_scorer(precision_score, average = 'macro'), 'accuracy': make_scorer(accuracy_score)}
grid_model = GridSearchCV(estimator=model, 
                          param_grid=params, 
                          cv=ps,
                          return_train_score=True,
                          scoring=scoring,
                             refit=False)

# %%
grid_model_result = grid_model.fit(train_data.loc[:,train_data.columns!=target],train_data[target])
# Out:
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Dt Results
cv_results = pd.DataFrame(grid_model.cv_results_)
cv_results.columns
ranked_cv=cv_results.sort_values(by=['rank_test_precision'])
ranked_cv[['param_criterion','param_max_depth','param_min_samples_split','rank_test_accuracy', 'mean_test_accuracy','mean_test_recall','mean_test_precision']]
# Out:
#    param_criterion param_max_depth param_min_samples_split  \
# 16         entropy               5                       5
# 15         entropy               5                       2
# 17         entropy               5                      10
# 7             gini               5                       5
# 6             gini               5                       2
# 8             gini               5                      10
# 4             gini               3                       5
# 3             gini               3                       2
# 5             gini               3                      10
# 2             gini               1                      10
# 9          entropy               1                       2
# 10         entropy               1                       5
# 11         entropy               1                      10
# 12         entropy               3                       2
# 13         entropy               3                       5
# 14         entropy               3                      10
# 1             gini               1                       5
# 0             gini               1                       2
#
#     rank_test_accuracy  mean_test_accuracy  mean_test_recall  \
# 16                  13            0.808490          0.502904
# 15                  14            0.808480          0.502898
# 17                  15            0.808403          0.502850
# 7                   16            0.808280          0.502979
# 6                   16            0.808280          0.502979
# 8                   18            0.808265          0.502970
# 4                   10            0.808510          0.499970
# 3                   10            0.808510          0.499970
# 5                   10            0.808510          0.499970
# 2                    1            0.808621          0.500000
# 9                    1            0.808621          0.500000
# 10                   1            0.808621          0.500000
# 11                   1            0.808621          0.500000
# 12                   1            0.808621          0.500000
# 13                   1            0.808621          0.500000
# 14                   1            0.808621          0.500000
# 1                    1            0.808621          0.500000
# 0                    1            0.808621          0.500000
#
#     mean_test_precision
# 16             0.652937
# 15             0.652425
# 17             0.648495
# 7              0.640676
# 6              0.640676
# 8              0.640061
# 4              0.436564
# 3              0.436564
# 5              0.436564
# 2              0.404311
# 9              0.404311
# 10             0.404311
# 11             0.404311
# 12             0.404311
# 13             0.404311
# 14             0.404311
# 1              0.404311
# 0              0.404311

# %%
labels = train_data.loc[:,train_data.columns!=target].columns.values
features = train_data.loc[:,train_data.columns!=target].values
target_vals = train_data[target].values

#dt = RandomForestClassifier(random_state=1234,max_depth=None,min_samples_split=5,criterion='gini',n_estimators=1000)
dt = DecisionTreeClassifier(random_state=1234,max_depth=5,min_samples_split=5,criterion='entropy')
model_dt = dt.fit(features,target_vals)

# %%
# prediction on test set
x_test = test_data.loc[:,test_data.columns!=target]
y_pred = model_dt.predict(x_test)
y_test = test_data.loc[:,target]

# %%
# Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
from sklearn.metrics import plot_confusion_matrix, classification_report, plot_roc_curve, plot_precision_recall_curve 

plot_confusion_matrix(model_dt,x_test,y_test)
print(metrics.confusion_matrix(y_test, y_pred))
# Out:
# [[128951      0]
#  [ 26831      0]]

# %%
MODELS = config.MODELS
PARAMS = config.PARAMS
model_key = "RandomForestClassifier"

model = MODELS[model_key]
params = PARAMS[model_key]        

target = config.target_vars[0]

# Include race/gender/ethnicity or exclude?
config.categorical_vars_to_impute
# Out:
# ['CONTROL_STATUS', 'OFFENSE_CLEAN', 'Current_Offense_Risk_Level', 'year_month']

# %%
#scorer = make_scorer(precision_score, average = None)
#gs_svc = GridSearchCV(estimator=svc_clf,param_grid=param_grid,scoring=scorer,cv=5)

#scoring = {'recall': make_scorer(recall_score, average = 'macro'), 'precision': make_scorer(precision_score, average = 'macro'), 'accuracy': make_scorer(accuracy_score)}
scoring = {'recall': make_scorer(recall_score), 'precision': make_scorer(precision_score), 'accuracy': make_scorer(accuracy_score)}

grid_model = GridSearchCV(estimator=model, 
                          param_grid=params, 
                          cv=ps,
                          return_train_score=True,
                          scoring=scoring,
                             refit=False)

# %%
rf_grid_model_result = grid_model.fit(train_data.loc[:,train_data.columns!=target],train_data[target])
# Out:
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
cv_results = pd.DataFrame(rf_grid_model_result.cv_results_)

ranked_cv=cv_results.sort_values(by=['rank_test_precision'])
ranked_cv[['param_criterion','param_max_depth','param_min_samples_split','param_n_estimators','rank_test_accuracy', 'mean_test_accuracy','mean_test_recall','mean_test_precision']]
# Out:
#    param_criterion param_max_depth param_min_samples_split param_n_estimators  \
# 0             gini               1                       2                100
# 29         entropy               1                       2               5000
# 30         entropy               1                       5                100
# 31         entropy               1                       5               1000
# 32         entropy               1                       5               5000
# 33         entropy               1                      10                100
# 34         entropy               1                      10               1000
# 35         entropy               1                      10               5000
# 36         entropy               3                       2                100
# 37         entropy               3                       2               1000
# 38         entropy               3                       2               5000
# 39         entropy               3                       5                100
# 40         entropy               3                       5               1000
# 41         entropy               3                       5               5000
# 42         entropy               3                      10                100
# 43         entropy               3                      10               1000
# 44         entropy               3                      10               5000
# 45         entropy               5                       2                100
# 46         entropy               5                       2               1000
# 47         entropy               5                       2               5000
# 48         entropy               5                       5                100
# 49         entropy               5                       5               1000
# 50         entropy               5                       5               5000
# 51         entropy               5                      10                100
# 28         entropy               1                       2               1000
# 27         entropy               1                       2                100
# 26            gini               5                      10               5000
# 25            gini               5                      10               1000
# 1             gini               1                       2               1000
# 2             gini               1                       2               5000
# 3             gini               1                       5                100
# 4             gini               1                       5               1000
# 5             gini               1                       5               5000
# 6             gini               1                      10                100
# 7             gini               1                      10               1000
# 8             gini               1                      10               5000
# 9             gini               3                       2                100
# 10            gini               3                       2               1000
# 11            gini               3                       2               5000
# 52         entropy               5                      10               1000
# 12            gini               3                       5                100
# 14            gini               3                       5               5000
# 15            gini               3                      10                100
# 16            gini               3                      10               1000
# 17            gini               3                      10               5000
# 18            gini               5                       2                100
# 19            gini               5                       2               1000
# 20            gini               5                       2               5000
# 21            gini               5                       5                100
# 22            gini               5                       5               1000
# 23            gini               5                       5               5000
# 24            gini               5                      10                100
# 13            gini               3                       5               1000
# 53         entropy               5                      10               5000
#
#     rank_test_accuracy  mean_test_accuracy  mean_test_recall  \
# 0                    1            0.808621               0.5
# 29                   1            0.808621               0.5
# 30                   1            0.808621               0.5
# 31                   1            0.808621               0.5
# 32                   1            0.808621               0.5
# 33                   1            0.808621               0.5
# 34                   1            0.808621               0.5
# 35                   1            0.808621               0.5
# 36                   1            0.808621               0.5
# 37                   1            0.808621               0.5
# 38                   1            0.808621               0.5
# 39                   1            0.808621               0.5
# 40                   1            0.808621               0.5
# 41                   1            0.808621               0.5
# 42                   1            0.808621               0.5
# 43                   1            0.808621               0.5
# 44                   1            0.808621               0.5
# 45                   1            0.808621               0.5
# 46                   1            0.808621               0.5
# 47                   1            0.808621               0.5
# 48                   1            0.808621               0.5
# 49                   1            0.808621               0.5
# 50                   1            0.808621               0.5
# 51                   1            0.808621               0.5
# 28                   1            0.808621               0.5
# 27                   1            0.808621               0.5
# 26                   1            0.808621               0.5
# 25                   1            0.808621               0.5
# 1                    1            0.808621               0.5
# 2                    1            0.808621               0.5
# 3                    1            0.808621               0.5
# 4                    1            0.808621               0.5
# 5                    1            0.808621               0.5
# 6                    1            0.808621               0.5
# 7                    1            0.808621               0.5
# 8                    1            0.808621               0.5
# 9                    1            0.808621               0.5
# 10                   1            0.808621               0.5
# 11                   1            0.808621               0.5
# 52                   1            0.808621               0.5
# 12                   1            0.808621               0.5
# 14                   1            0.808621               0.5
# 15                   1            0.808621               0.5
# 16                   1            0.808621               0.5
# 17                   1            0.808621               0.5
# 18                   1            0.808621               0.5
# 19                   1            0.808621               0.5
# 20                   1            0.808621               0.5
# 21                   1            0.808621               0.5
# 22                   1            0.808621               0.5
# 23                   1            0.808621               0.5
# 24                   1            0.808621               0.5
# 13                   1            0.808621               0.5
# 53                   1            0.808621               0.5
#
#     mean_test_precision
# 0              0.404311
# 29             0.404311
# 30             0.404311
# 31             0.404311
# 32             0.404311
# 33             0.404311
# 34             0.404311
# 35             0.404311
# 36             0.404311
# 37             0.404311
# 38             0.404311
# 39             0.404311
# 40             0.404311
# 41             0.404311
# 42             0.404311
# 43             0.404311
# 44             0.404311
# 45             0.404311
# 46             0.404311
# 47             0.404311
# 48             0.404311
# 49             0.404311
# 50             0.404311
# 51             0.404311
# 28             0.404311
# 27             0.404311
# 26             0.404311
# 25             0.404311
# 1              0.404311
# 2              0.404311
# 3              0.404311
# 4              0.404311
# 5              0.404311
# 6              0.404311
# 7              0.404311
# 8              0.404311
# 9              0.404311
# 10             0.404311
# 11             0.404311
# 52             0.404311
# 12             0.404311
# 14             0.404311
# 15             0.404311
# 16             0.404311
# 17             0.404311
# 18             0.404311
# 19             0.404311
# 20             0.404311
# 21             0.404311
# 22             0.404311
# 23             0.404311
# 24             0.404311
# 13             0.404311
# 53             0.404311

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re
# %matplotlib inline

# %%
labels = train_data.loc[:,train_data.columns!=target].columns.values
features = train_data.loc[:,train_data.columns!=target].values
target_vals = train_data[target].values

dt = RandomForestClassifier(random_state=1234,max_depth=30,min_samples_split=5,criterion='gini',n_estimators=1000)
model_rf = dt.fit(features,target_vals)

# Get feature importances
importances = model_rf.feature_importances_

# Sort in descending order
indices = np.argsort(importances)[::-1]

# Sort the labels in a corresponding fashion
names = [labels[i] for i in indices]

# Plot
plt.figure()
plt.bar(range(features.shape[1]),importances[indices])
plt.xticks(range(features.shape[1]), names, rotation=90)
plt.show()

# %%
# prediction on test set
x_test = test_data.loc[:,test_data.columns!=target]
y_pred = model_rf.predict(x_test)
y_test = test_data.loc[:,target]

# %%
# Import scikit-learn metrics module for accuracy calculation
#from sklearn import metrics
from sklearn.metrics import plot_confusion_
# Out:
# ---------------------------------------------------------
# ImportError             Traceback (most recent call last)
# <ipython-input-13-acc725853191> in <module>
#       1 # Import scikit-learn metrics module for accuracy calculation
#       2 #from sklearn import metrics
# ----> 3 from sklearn.metrics import plot_confusion_
#
# ImportError: cannot import name 'plot_confusion_' from 'sklearn.metrics' (/Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/__init__.py)

# %%
matrix, classification_report, plot_roc_curve, plot_precision_recall_curve 

plot_confusion_matrix(model_rf,x_test,y_test)
print(metrics.confusion_matrix(y_test, y_pred))
# Out:
# [[128934     17]
#  [ 26790     41]]

# %%
names[:20]
# Out:
# ['sentence_count',
#  'age_first_offense',
#  'age_at_sentence',
#  'INFRACTION_PER_SENT',
#  'misd_count',
#  'unemp_rate',
#  'felon_count',
#  'juv_first_offense',
#  'OFFENSE_CLEAN_LARCENY (OVER $200)',
#  'Current_Offense_Risk_Level_1.0',
#  'age_cat_18-21',
#  'OFFENSE_CLEAN_LARCENY',
#  'Current_Offense_Risk_Level_3.0',
#  'OFFENSE_CLEAN_FELONY B&E',
#  'age_cat_Under 18',
#  'CONTROL_STATUS_REGULAR POPULATION        RPOP',
#  'OFFENSE_CLEAN_MISD B&E',
#  'OFFENSE_CLEAN_ROBBERY W/DANGEROUS WEAPON',
#  'Current_Offense_Risk_Level_2.0',
#  'OFFENSE_CLEAN_OTHER']

# %%
# Sort in descending order
indices = np.argsort(importances)[::-1]

# Sort the labels in a corresponding fashion
names = [labels[i] for i in indices]

# Plot
plt.figure()
plt.bar(range(20),importances[indices[:20]])
plt.xticks(range(20), names[:20], rotation=90)
plt.show()

# %%
# TRY A SMALL SUBSET WTF IS GOING ON WIHT OUR MODELS ABOVE

# %%
# subset
subset_vars = names[:40]

train_subset = train_data.loc[:,subset_vars+[target]]
validate_subset = validate_data.loc[:,subset_vars+[target]]

ps = PredefinedSplit(test_fold=validate_subset[target])

# %%
importlib.reload(config)
# Out:
# <module 'config' from '/Users/daminisharma/Dropbox/Harris MSCAPP/2019-20_Q3_Spring/Machine Learning/covid_decarceration/files/config.py'>

# %%
MODELS = config.MODELS
PARAMS = config.PARAMS
model_key = "RandomForestClassifier"

model = MODELS[model_key]
params = PARAMS[model_key]        

#target = config.target_vars[0]

# Include race/gender/ethnicity or exclude?
config.categorical_vars_to_impute
params
# Out:
# {'criterion': ('gini', 'entropy'),
#  'n_estimators': (10, 20, 30, 100, 1000),
#  'max_depth': (10, 20, 30, None),
#  'min_samples_split': (5, 50, 100)}

# %%
#scorer = make_scorer(precision_score, average = None)
#gs_svc = GridSearchCV(estimator=svc_clf,param_grid=param_grid,scoring=scorer,cv=5)

scoring = {'recall': make_scorer(recall_score), 'precision': make_scorer(precision_score), 'accuracy': make_scorer(accuracy_score)}
grid_model = GridSearchCV(estimator=model, 
                          param_grid=params, 
                          cv=ps,
                          return_train_score=True,
                          scoring=scoring,
                             refit=False)

# %%
#grid_model_result_dt = grid_model.fit(train_subset.loc[:,train_subset.columns!=target],train_subset[target])
grid_model_result_rf = grid_model.fit(train_subset.loc[:,train_subset.columns!=target],train_subset[target])
# Out:
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Dt Results
# cv_results = pd.DataFrame(grid_model_result_dt.cv_results_)
# cv_results.columns
# ranked_cv=cv_results.sort_values(by=['rank_test_recall'])
# ranked_cv[['param_criterion','param_max_depth','param_min_samples_split','rank_test_accuracy', 'mean_test_accuracy','mean_test_recall','mean_test_precision']]

# # cv_results = pd.DataFrame(grid_model.cv_results_)

# # ranked_cv=cv_results.sort_values(by=['rank_test_precision'])
# # ranked_cv[['param_C','param_max_iter','param_penalty','rank_test_accuracy', 'mean_test_accuracy','mean_test_recall','mean_test_precision']]

cv_results = pd.DataFrame(grid_model_result_rf.cv_results_)

ranked_cv=cv_results.sort_values(by=['rank_test_precision'])
ranked_cv[['param_criterion','param_max_depth','param_min_samples_split','param_n_estimators','rank_test_accuracy', 'mean_test_accuracy','mean_test_recall','mean_test_precision']]



#grid_model_result_rf
# Out:
#     param_criterion param_max_depth param_min_samples_split  \
# 73          entropy              10                     100
# 7              gini              10                      50
# 11             gini              10                     100
# 72          entropy              10                     100
# 61          entropy              10                       5
# 68          entropy              10                      50
# 63          entropy              10                       5
# 62          entropy              10                       5
# 8              gini              10                      50
# 71          entropy              10                     100
# 6              gini              10                      50
# 9              gini              10                      50
# 60          entropy              10                       5
# 12             gini              10                     100
# 5              gini              10                      50
# 29             gini              20                     100
# 13             gini              10                     100
# 69          entropy              10                      50
# 88          entropy              20                     100
# 65          entropy              10                      50
# 86          entropy              20                     100
# 4              gini              10                       5
# 14             gini              10                     100
# 89          entropy              20                     100
# 102         entropy              30                     100
# 44             gini              30                     100
# 67          entropy              10                      50
# 118         entropy            None                     100
# 87          entropy              20                     100
# 104         entropy              30                     100
# 119         entropy            None                     100
# 103         entropy              30                     100
# 64          entropy              10                       5
# 59             gini            None                     100
# 43             gini              30                     100
# 28             gini              20                     100
# 58             gini            None                     100
# 27             gini              20                     100
# 101         entropy              30                     100
# 116         entropy            None                     100
# 41             gini              30                     100
# 22             gini              20                      50
# 42             gini              30                     100
# 66          entropy              10                      50
# 23             gini              20                      50
# 84          entropy              20                      50
# 38             gini              30                      50
# 3              gini              10                       5
# 83          entropy              20                      50
# 1              gini              10                       5
# 24             gini              20                      50
# 117         entropy            None                     100
# 54             gini            None                      50
# 52             gini            None                      50
# 56             gini            None                     100
# 99          entropy              30                      50
# 39             gini              30                      50
# 53             gini            None                      50
# 114         entropy            None                      50
# 2              gini              10                       5
# 113         entropy            None                      50
# 21             gini              20                      50
# 26             gini              20                     100
# 57             gini            None                     100
# 98          entropy              30                      50
# 85          entropy              20                     100
# 40             gini              30                     100
# 81          entropy              20                      50
# 20             gini              20                      50
# 96          entropy              30                      50
# 115         entropy            None                     100
# 100         entropy              30                     100
# 25             gini              20                     100
# 97          entropy              30                      50
# 55             gini            None                     100
# 51             gini            None                      50
# 112         entropy            None                      50
# 10             gini              10                     100
# 111         entropy            None                      50
# 82          entropy              20                      50
# 80          entropy              20                      50
# 37             gini              30                      50
# 0              gini              10                       5
# 70          entropy              10                     100
# 50             gini            None                      50
# 36             gini              30                      50
# 79          entropy              20                       5
# 78          entropy              20                       5
# 19             gini              20                       5
# 110         entropy            None                      50
# 95          entropy              30                      50
# 18             gini              20                       5
# 77          entropy              20                       5
# 35             gini              30                      50
# 76          entropy              20                       5
# 17             gini              20                       5
# 16             gini              20                       5
# 75          entropy              20                       5
# 94          entropy              30                       5
# 34             gini              30                       5
# 93          entropy              30                       5
# 15             gini              20                       5
# 33             gini              30                       5
# 92          entropy              30                       5
# 49             gini            None                       5
# 91          entropy              30                       5
# 109         entropy            None                       5
# 48             gini            None                       5
# 108         entropy            None                       5
# 32             gini              30                       5
# 31             gini              30                       5
# 107         entropy            None                       5
# 46             gini            None                       5
# 47             gini            None                       5
# 106         entropy            None                       5
# 90          entropy              30                       5
# 45             gini            None                       5
# 105         entropy            None                       5
# 74          entropy              10                     100
# 30             gini              30                       5
#
#     param_n_estimators  rank_test_accuracy  mean_test_accuracy  \
# 73                 100                  86            0.808718
# 7                   30                  68            0.808947
# 11                  20                  73            0.808891
# 72                  30                  85            0.808724
# 61                  20                  58            0.809141
# 68                 100                  84            0.808748
# 63                 100                  72            0.808915
# 62                  30                  61            0.809070
# 8                  100                  78            0.808823
# 71                  20                  80            0.808776
# 6                   20                  70            0.808933
# 9                 1000                  81            0.808754
# 60                  10                  51            0.809256
# 12                  30                  90            0.808689
# 5                   10                  66            0.808970
# 29                1000                  49            0.809265
# 13                 100                  88            0.808691
# 69                1000                  87            0.808707
# 88                 100                  31            0.809435
# 65                  10                  56            0.809198
# 86                  20                  14            0.809712
# 4                 1000                  67            0.808961
# 14                1000                  91            0.808686
# 89                1000                  46            0.809272
# 102                 30                  26            0.809484
# 44                1000                  43            0.809288
# 67                  30                  79            0.808809
# 118                100                  38            0.809332
# 87                  30                  33            0.809423
# 104               1000                  42            0.809303
# 119               1000                  44            0.809280
# 103                100                  37            0.809352
# 64                1000                  76            0.808867
# 59                1000                  45            0.809279
# 43                 100                  47            0.809269
# 28                 100                  50            0.809261
# 58                 100                  57            0.809173
# 27                  30                  39            0.809327
# 101                 20                  24            0.809530
# 116                 20                  32            0.809431
# 41                  20                  34            0.809400
# 22                  30                   2            0.810034
# 42                  30                  41            0.809317
# 66                  20                  75            0.808885
# 23                 100                   7            0.809799
# 84                1000                  16            0.809686
# 38                 100                   4            0.809857
# 3                  100                  69            0.808938
# 83                 100                   5            0.809823
# 1                   20                  65            0.809008
# 24                1000                  15            0.809691
# 117                 30                  54            0.809234
# 54                1000                   8            0.809792
# 52                  30                   1            0.810047
# 56                  20                  40            0.809321
# 99                1000                  13            0.809756
# 39                1000                  10            0.809768
# 53                 100                   9            0.809781
# 114               1000                  17            0.809684
# 2                   30                  71            0.808921
# 113                100                  11            0.809766
# 21                  20                   3            0.809903
# 26                  20                  59            0.809126
# 57                  30                  60            0.809076
# 98                 100                  21            0.809652
# 85                  10                  28            0.809468
# 40                  10                  26            0.809484
# 81                  20                  18            0.809678
# 20                  10                   5            0.809823
# 96                  20                  12            0.809758
# 115                 10                  30            0.809449
# 100                 10                  23            0.809561
# 25                  10                  36            0.809376
# 97                  30                  25            0.809492
# 55                  10                  52            0.809245
# 51                  20                  19            0.809666
# 112                 30                  29            0.809452
# 10                  10                  81            0.808754
# 111                 20                  22            0.809617
# 82                  30                  48            0.809268
# 80                  10                  20            0.809661
# 37                  30                  55            0.809201
# 0                   10                  77            0.808858
# 70                  10                  83            0.808749
# 50                  10                  35            0.809382
# 36                  20                  61            0.809070
# 79                1000                  53            0.809238
# 78                 100                  63            0.809041
# 19                1000                  64            0.809020
# 110                 10                  74            0.808889
# 95                  10                  92            0.808678
# 18                 100                  93            0.808572
# 77                  30                  95            0.808458
# 35                  10                  94            0.808546
# 76                  20                  96            0.807718
# 17                  30                  97            0.807360
# 16                  20                  98            0.806053
# 75                  10                  99            0.804091
# 94                1000                 100            0.803029
# 34                1000                 101            0.802948
# 93                 100                 103            0.802353
# 15                  10                 102            0.802441
# 33                 100                 104            0.802104
# 92                  30                 107            0.799421
# 49                1000                 105            0.800303
# 91                  20                 111            0.797830
# 109               1000                 106            0.799735
# 48                 100                 108            0.799115
# 108                100                 109            0.798940
# 32                  30                 110            0.798779
# 31                  20                 112            0.796791
# 107                 30                 113            0.796369
# 46                  20                 115            0.794966
# 47                  30                 114            0.796091
# 106                 20                 116            0.793242
# 90                  10                 117            0.791020
# 45                  10                 119            0.788779
# 105                 10                 120            0.788599
# 74                1000                  89            0.808690
# 30                  10                 118            0.789368
#
#      mean_test_recall  mean_test_precision
# 73           0.000857             0.850000
# 7            0.002817             0.797619
# 11           0.002529             0.781469
# 72           0.001035             0.762626
# 61           0.004701             0.737145
# 68           0.001213             0.734848
# 63           0.002529             0.719958
# 62           0.003852             0.719697
# 8            0.002249             0.715062
# 71           0.001765             0.696860
# 6            0.003504             0.692036
# 9            0.001587             0.676339
# 60           0.007679             0.676119
# 12           0.001621             0.675000
# 5            0.003742             0.672414
# 29           0.009673             0.664474
# 13           0.000916             0.663636
# 69           0.001290             0.660535
# 88           0.010318             0.655513
# 65           0.006381             0.654189
# 86           0.013347             0.653657
# 4            0.003513             0.652941
# 14           0.000891             0.650000
# 89           0.010055             0.649457
# 102          0.012906             0.647580
# 44           0.010233             0.647059
# 67           0.002223             0.645455
# 118          0.011328             0.643402
# 87           0.010895             0.641935
# 104          0.010768             0.641659
# 119          0.010530             0.640544
# 103          0.011260             0.640406
# 64           0.002664             0.636578
# 59           0.010428             0.635090
# 43           0.010878             0.628488
# 28           0.010539             0.623266
# 58           0.010522             0.618371
# 27           0.012024             0.617538
# 101          0.014315             0.615809
# 116          0.013661             0.615424
# 41           0.013432             0.615263
# 22           0.019432             0.614871
# 42           0.011786             0.614748
# 66           0.003428             0.613656
# 23           0.017633             0.611508
# 84           0.016445             0.610518
# 38           0.018812             0.608123
# 3            0.004226             0.608093
# 83           0.018354             0.605794
# 1            0.007119             0.604806
# 24           0.017370             0.604108
# 117          0.012304             0.603222
# 54           0.019041             0.601763
# 52           0.021689             0.601199
# 56           0.012957             0.599128
# 99           0.019211             0.599048
# 39           0.018761             0.598724
# 53           0.019151             0.598645
# 114          0.018210             0.596652
# 2            0.004803             0.595924
# 113          0.019525             0.590529
# 21           0.022020             0.589281
# 26           0.011566             0.585509
# 57           0.010759             0.581346
# 98           0.020509             0.580261
# 85           0.016911             0.575678
# 40           0.017692             0.574599
# 81           0.022817             0.566996
# 20           0.026534             0.566486
# 96           0.025626             0.566362
# 115          0.018642             0.565027
# 100          0.021264             0.564602
# 25           0.017268             0.563099
# 97           0.021256             0.562369
# 55           0.016368             0.562208
# 51           0.024243             0.561781
# 112          0.021477             0.557040
# 10           0.003649             0.556534
# 111          0.026856             0.552780
# 82           0.018244             0.551663
# 80           0.027476             0.551000
# 37           0.018778             0.550386
# 0            0.010700             0.550139
# 70           0.002826             0.541071
# 50           0.031108             0.532673
# 36           0.020755             0.529729
# 79           0.035342             0.526722
# 78           0.036750             0.516262
# 19           0.038957             0.516239
# 110          0.030785             0.511634
# 95           0.029937             0.503343
# 18           0.041027             0.502416
# 77           0.042334             0.496202
# 35           0.024760             0.495495
# 76           0.047425             0.479701
# 17           0.048749             0.472032
# 16           0.054146             0.446815
# 75           0.057226             0.416131
# 94           0.064684             0.407420
# 34           0.065669             0.406651
# 93           0.070302             0.405247
# 15           0.064515             0.403376
# 33           0.068061             0.398911
# 92           0.079610             0.383762
# 49           0.069903             0.382630
# 91           0.087671             0.378475
# 109          0.070836             0.377535
# 48           0.075834             0.377300
# 108          0.076343             0.376797
# 32           0.076818             0.374642
# 31           0.084846             0.366616
# 107          0.084608             0.364843
# 46           0.092796             0.361361
# 47           0.082572             0.358973
# 106          0.090989             0.349130
# 90           0.101163             0.343968
# 45           0.108181             0.337993
# 105          0.106068             0.335106
# 74           0.000713             0.333333
# 30           0.098516             0.331288

# %%
labels = train_data.loc[:,train_data.columns!=target].columns.values
features = train_data.loc[:,train_data.columns!=target].values
target_vals = train_data[target].values

rf = RandomForestClassifier(random_state=1234,max_depth=None,min_samples_split=5,criterion='gini',n_estimators=100)
#rf_highest_precision = RandomForestClassifier(random_state=1234,max_depth=10,min_samples_split=100,criterion='entropy',n_estimators=100)

#dt = DecisionTreeClassifier(random_state=1234,max_depth=5,min_samples_split=5,criterion='entropy')
#dt = LogisticRegression(random_state=1234,C=0.01,max_iter=1000,penalty='l2')

# %%
# model_rf_recall = rf_highest_recall.fit(features,target_vals)
# model_rf_precision = rf_highest_precision.fit(features,target_vals)

model_rf_all = rf.fit(features,target_vals)

# %%
#test_subset = test_data.loc[:,subset_vars+[target]]
# cv_results = pd.DataFrame(grid_model_result_rf.cv_results_)

# ranked_cv=cv_results.sort_values(by=['rank_test_precision'])
# ranked_cv[['param_criterion','param_max_depth','param_min_samples_split','param_n_estimators','rank_test_accuracy', 'mean_test_accuracy','mean_test_recall','mean_test_precision']]

# %%
# prediction on test set
# x_test_rf_recall = test_subset.loc[:,test_subset.columns!=target]
# y_pred_rf_recall = model_rf_recall.predict(x_test_rf_recall)
# y_test_rf_recall = test_subset.loc[:,target]

# x_test_rf_precision = test_subset.loc[:,test_subset.columns!=target]
# y_pred_rf_precision = model_rf_precision.predict(x_test_rf_precision)
# y_test_rf_precision = test_subset.loc[:,target]

x_test_rf = test_data.loc[:,test_data.columns!=target]
y_pred_rf = model_rf_all.predict(x_test_rf)
y_test_rf = test_data.loc[:,target]

# %%
# Import scikit-learn metrics module for accuracy calculation
#from sklearn import metrics
#from sklearn.metrics import plot_confusion_matrix, classification_report, plot_roc_curve, plot_precision_recall_curve 

plot_confusion_matrix(model_rf_all,x_test_rf,y_test_rf)
print(metrics.confusion_matrix(y_test_rf, y_pred_rf))
# Out:
# [[127312   1639]
#  [ 25548   1283]]

# %%
print("Accuracy:\t{}\nPrecision:\t{}\nRecall:\t\t{}\nF1 Score:\t{}\n".format(accuracy_score(y_test_rf, y_pred_rf),
                                                                           precision_score(y_test_rf, y_pred_rf),
                                                                           recall_score(y_test_rf, y_pred_rf),
                                                                           f1_score(y_test_rf, y_pred_rf)
                                                                          ))
# Out:
# Accuracy:	0.8254804791310935
# Precision:	0.43908281998631077
# Recall:		0.04781782266780962
# F1 Score:	0.08624340402648473

# %%
# Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
from sklearn.metrics import plot_confusion_matrix, classification_report, plot_roc_curve, plot_precision_recall_curve 

plot_confusion_matrix(model_rf_precision,x_test_rf_precision,y_test_rf_precision)
print(metrics.confusion_matrix(y_test_rf_precision, y_pred_rf_precision))
# Out:
# [[128946      5]
#  [ 26815     16]]

# %%
importlib.reload(config)
# Out:
# <module 'config' from '/Users/daminisharma/Dropbox/Harris MSCAPP/2019-20_Q3_Spring/Machine Learning/covid_decarceration/files/config.py'>

# %%
MODELS = config.MODELS
PARAMS = config.PARAMS
model_key = "GaussianNB"

model = MODELS[model_key]
params = PARAMS[model_key]        

target = config.target_vars[0]

# Include race/gender/ethnicity or exclude?
config.categorical_vars_to_impute
# Out:
# ['CONTROL_STATUS', 'OFFENSE_CLEAN', 'Current_Offense_Risk_Level', 'year_month']

# %%
#scorer = make_scorer(precision_score, average = None)
#gs_svc = GridSearchCV(estimator=svc_clf,param_grid=param_grid,scoring=scorer,cv=5)

scoring = {'recall': make_scorer(recall_score), 'precision': make_scorer(precision_score), 'accuracy': make_scorer(accuracy_score)}
grid_model = GridSearchCV(estimator=model, 
                          param_grid=params, 
                          cv=ps,
                          return_train_score=True,
                          scoring=scoring,
                             refit=False)

# %%
#grid_model_result_dt = grid_model.fit(train_subset.loc[:,train_subset.columns!=target],train_subset[target])
#grid_model_result_nb = grid_model.fit(train_subset.loc[:,train_subset.columns!=target],train_subset[target])
grid_model_result_nb = grid_model.fit(train_data.loc[:,train_data.columns!=target],train_data[target])

# %%
cv_results = pd.DataFrame(grid_model_result_nb.cv_results_)

ranked_cv=cv_results.sort_values(by=['rank_test_precision'])
ranked_cv[['param_priors','rank_test_accuracy', 'mean_test_accuracy','mean_test_recall','mean_test_precision']]
#cv_results.columns
# Out:
#   param_priors  rank_test_accuracy  mean_test_accuracy  mean_test_recall  \
# 0         None                   1            0.293964          0.911896
#
#    mean_test_precision
# 0             0.202096

# %%
labels = train_data.loc[:,train_data.columns!=target].columns.values
features = train_data.loc[:,train_data.columns!=target].values
target_vals = train_data[target].values

nb = GaussianNB()

model_nb = nb.fit(features,target_vals)

x_test_nb = test_data.loc[:,test_data.columns!=target]
y_pred_nb = nb.predict(x_test_nb)
y_test_nb = test_data.loc[:,target]

# %%
print(nb)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
df = pd.DataFrame(y_pred_nb)

# %%
df[0].unique()
# Out:
# array([1., 0.])

# %%
plot_precision_recall_curve(model_nb,x_test_nb,y_test_nb)
plt.show()

# %%
print("Accuracy:\t{}\nPrecision:\t{}\nRecall:\t\t{}\nF1 Score:\t{}\n".format(accuracy_score(y_test_nb, y_pred_nb),
                                                                           precision_score(y_test_nb, y_pred_nb),
                                                                           recall_score(y_test_nb, y_pred_nb),
                                                                           f1_score(y_test_nb, y_pred_nb)
                                                                          ))
# Out:
# Accuracy:	0.4659074861023738
# Precision:	0.20717884785205964
# Recall:		0.7432447542022288
# F1 Score:	0.324033602521814

# %%
plot_confusion_matrix(nb,x_test_nb,y_pred_nb)
print(metrics.confusion_matrix(y_test_nb, y_pred_nb))
# Out:
# [[52638 76313]
#  [ 6889 19942]]

# %%
MODELS = config.MODELS
PARAMS = config.PARAMS
model_key = "LinearSVC"

model = MODELS[model_key]
params = PARAMS[model_key]        

target = config.target_vars[0]

# Include race/gender/ethnicity or exclude?
config.categorical_vars_to_impute
# Out:
# ['CONTROL_STATUS', 'OFFENSE_CLEAN', 'Current_Offense_Risk_Level', 'year_month']

# %%
#scorer = make_scorer(precision_score, average = None)
#gs_svc = GridSearchCV(estimator=svc_clf,param_grid=param_grid,scoring=scorer,cv=5)

scoring = {'recall': make_scorer(recall_score), 'precision': make_scorer(precision_score), 'accuracy': make_scorer(accuracy_score)}
grid_model = GridSearchCV(estimator=model, 
                          param_grid=params, 
                          cv=ps,
                          return_train_score=True,
                          scoring=scoring,
                             refit=False)

# %%
grid_model_result_svc = grid_model.fit(train_data.loc[:,train_data.columns!=target],train_data[target])
# Out:
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
cv_results = pd.DataFrame(grid_model_result_svc.cv_results_)

ranked_cv=cv_results.sort_values(by=['rank_test_precision'])
ranked_cv[['params','rank_test_accuracy', 'mean_test_accuracy','mean_test_recall','mean_test_precision']]
#cv_results.columns
# Out:
#         params  rank_test_accuracy  mean_test_accuracy  mean_test_recall  \
# 0  {'C': 0.01}                   1            0.809386          0.018371
# 2     {'C': 1}                   2            0.809161          0.020127
# 1   {'C': 0.1}                   3            0.809121          0.022037
# 4   {'C': 100}                   4            0.502885          0.500653
# 3    {'C': 10}                   5            0.502052          0.505889
#
#    mean_test_precision
# 0             0.563290
# 2             0.537638
# 1             0.536663
# 4             0.513246
# 3             0.372763

# %%
svc = LinearSVC(random_state=1234,C=100)

model_svc = svc.fit(features,target_vals)

x_test_svc = test_data.loc[:,test_data.columns!=target]
y_pred_svc = svc.predict(x_test_svc)
y_test_svc = test_data.loc[:,target]
# Out:
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
plot_confusion_matrix(svc,x_test_svc,y_pred_svc)
print(metrics.confusion_matrix(y_test_svc, y_pred_svc))
# Out:
# [[128920     31]
#  [ 26779     52]]

# %%
print("Accuracy:\t{}\nPrecision:\t{}\nRecall:\t\t{}\nF1 Score:\t{}\n".format(accuracy_score(y_test_svc, y_pred_svc),
                                                                           precision_score(y_test_svc, y_pred_svc),
                                                                           recall_score(y_test_svc, y_pred_svc),
                                                                           f1_score(y_test_svc, y_pred_svc)
                                                                          ))
# Out:
# Accuracy:	0.8279005276604485
# Precision:	0.6265060240963856
# Recall:		0.0019380567254295405
# F1 Score:	0.0038641599167719403

# %%
# THREE CLASS VAR

# %%
# 5 CLASS VAR

# %%
#model = LogisticRegression(random_state=1234, solver='lbfgs')

# %%
#model.fit(train_data.loc[:,train_data.columns!=target],train_data[target])

# %%
#validate_predict = model.predict(validate_data.loc[:,validate_data.columns!=target])

# %%
#accuracy = accuracy_score(validate_data[target],validate_predict)

# %%
#accuracy

# %%
print("Accuracy:\t{}\nPrecision:\t{}\nRecall:\t\t{}\nF1 Score:\t{}\n".format(accuracy_score(validate_data[target], validate_predict),
                                                                           precision_score(validate_data[target], validate_predict,average=None),
                                                                           recall_score(validate_data[target], validate_predict,average=None),
                                                                           f1_score(validate_data[target], validate_predict,average=None)
                                                                          ))
# Out:
# Accuracy:	0.8230410917313178
# Precision:	[0.82725468 0.15324675 0.11285266 0.14035088 0.         0.        ]
# Recall:		[0.9961088  0.00917431 0.00591522 0.00115274 0.         0.        ]
# F1 Score:	[0.9038633  0.01731221 0.01124122 0.00228669 0.         0.        ]
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#train_data.dtypes

# %%
test_data.groupby(target).count()
# Out:
#                        INFRACTION_PER_SENT  misd_count  felon_count  \
# Recidivate_Risk_Level
# 0.0                                 128951      128951       128951
# 1.0                                   7755        7755         7755
# 2.0                                   7388        7388         7388
# 3.0                                   8647        8647         8647
# 4.0                                   2528        2528         2528
# 5.0                                    513         513          513
#
#                        sentence_count  age_at_sentence  unemp_rate  \
# Recidivate_Risk_Level
# 0.0                            128951           128951      128951
# 1.0                              7755             7755        7755
# 2.0                              7388             7388        7388
# 3.0                              8647             8647        8647
# 4.0                              2528             2528        2528
# 5.0                               513              513         513
#
#                        age_first_offense  juv_first_offense  \
# Recidivate_Risk_Level
# 0.0                               128951             128951
# 1.0                                 7755               7755
# 2.0                                 7388               7388
# 3.0                                 8647               8647
# 4.0                                 2528               2528
# 5.0                                  513                513
#
#                        current_crime_violent  RACE_ASIAN/ORTL  RACE_BLACK  \
# Recidivate_Risk_Level
# 0.0                                   128951           128951      128951
# 1.0                                     7755             7755        7755
# 2.0                                     7388             7388        7388
# 3.0                                     8647             8647        8647
# 4.0                                     2528             2528        2528
# 5.0                                      513              513         513
#
#                        RACE_INDIAN  RACE_OTHER  RACE_UNKNOWN  RACE_WHITE  \
# Recidivate_Risk_Level
# 0.0                         128951      128951        128951      128951
# 1.0                           7755        7755          7755        7755
# 2.0                           7388        7388          7388        7388
# 3.0                           8647        8647          8647        8647
# 4.0                           2528        2528          2528        2528
# 5.0                            513         513           513         513
#
#                        GENDER_FEMALE  GENDER_MALE  ETHNICITY_AFRICAN  \
# Recidivate_Risk_Level
# 0.0                           128951       128951             128951
# 1.0                             7755         7755               7755
# 2.0                             7388         7388               7388
# 3.0                             8647         8647               8647
# 4.0                             2528         2528               2528
# 5.0                              513          513                513
#
#                        ETHNICITY_AMERICAN INDIAN  ETHNICITY_ASIAN  \
# Recidivate_Risk_Level
# 0.0                                       128951           128951
# 1.0                                         7755             7755
# 2.0                                         7388             7388
# 3.0                                         8647             8647
# 4.0                                         2528             2528
# 5.0                                          513              513
#
#                        ETHNICITY_EUROPEAN/N.AM./AUSTR  \
# Recidivate_Risk_Level
# 0.0                                            128951
# 1.0                                              7755
# 2.0                                              7388
# 3.0                                              8647
# 4.0                                              2528
# 5.0                                               513
#
#                        ETHNICITY_HISPANIC/LATINO  \
# Recidivate_Risk_Level
# 0.0                                       128951
# 1.0                                         7755
# 2.0                                         7388
# 3.0                                         8647
# 4.0                                         2528
# 5.0                                          513
#
#                        ETHNICITY_NORDIC/SCANDANAVIAN  ETHNICITY_ORIENTAL  \
# Recidivate_Risk_Level
# 0.0                                           128951              128951
# 1.0                                             7755                7755
# 2.0                                             7388                7388
# 3.0                                             8647                8647
# 4.0                                             2528                2528
# 5.0                                              513                 513
#
#                        ETHNICITY_OTHER  ETHNICITY_PACIFIC ISLANDER  \
# Recidivate_Risk_Level
# 0.0                             128951                      128951
# 1.0                               7755                        7755
# 2.0                               7388                        7388
# 3.0                               8647                        8647
# 4.0                               2528                        2528
# 5.0                                513                         513
#
#                        ETHNICITY_SLAVIC (E. EUROPEAN)  ETHNICITY_UNKNOWN  \
# Recidivate_Risk_Level
# 0.0                                            128951             128951
# 1.0                                              7755               7755
# 2.0                                              7388               7388
# 3.0                                              8647               8647
# 4.0                                              2528               2528
# 5.0                                               513                513
#
#                        CONTROL_STATUS_HIGH SECURITY/MAX CONTROL HCON  \
# Recidivate_Risk_Level
# 0.0                                                           128951
# 1.0                                                             7755
# 2.0                                                             7388
# 3.0                                                             8647
# 4.0                                                             2528
# 5.0                                                              513
#
#                        CONTROL_STATUS_INTENSIVE CONTROL         ICON  \
# Recidivate_Risk_Level
# 0.0                                                           128951
# 1.0                                                             7755
# 2.0                                                             7388
# 3.0                                                             8647
# 4.0                                                             2528
# 5.0                                                              513
#
#                        CONTROL_STATUS_MAXIMUM CONTROL           MCON  \
# Recidivate_Risk_Level
# 0.0                                                           128951
# 1.0                                                             7755
# 2.0                                                             7388
# 3.0                                                             8647
# 4.0                                                             2528
# 5.0                                                              513
#
#                        CONTROL_STATUS_MODIFIED HOUSING          MODH  \
# Recidivate_Risk_Level
# 0.0                                                           128951
# 1.0                                                             7755
# 2.0                                                             7388
# 3.0                                                             8647
# 4.0                                                             2528
# 5.0                                                              513
#
#                        CONTROL_STATUS_OUT OF CELL RESTRICTION   OUTC  \
# Recidivate_Risk_Level
# 0.0                                                           128951
# 1.0                                                             7755
# 2.0                                                             7388
# 3.0                                                             8647
# 4.0                                                             2528
# 5.0                                                              513
#
#                        CONTROL_STATUS_PROTECTIVE CONTROL        PCON  \
# Recidivate_Risk_Level
# 0.0                                                           128951
# 1.0                                                             7755
# 2.0                                                             7388
# 3.0                                                             8647
# 4.0                                                             2528
# 5.0                                                              513
#
#                        CONTROL_STATUS_REGULAR POPULATION        RPOP  \
# Recidivate_Risk_Level
# 0.0                                                           128951
# 1.0                                                             7755
# 2.0                                                             7388
# 3.0                                                             8647
# 4.0                                                             2528
# 5.0                                                              513
#
#                        CONTROL_STATUS_REST.HOUS. ADMINISTRATIVE RHAP  \
# Recidivate_Risk_Level
# 0.0                                                           128951
# 1.0                                                             7755
# 2.0                                                             7388
# 3.0                                                             8647
# 4.0                                                             2528
# 5.0                                                              513
#
#                        CONTROL_STATUS_REST.HOUS. DISCIPLINARY   RHDP  \
# Recidivate_Risk_Level
# 0.0                                                           128951
# 1.0                                                             7755
# 2.0                                                             7388
# 3.0                                                             8647
# 4.0                                                             2528
# 5.0                                                              513
#
#                        CONTROL_STATUS_RESTRCT HOUSNG 4 CTL PURP RHCP  \
# Recidivate_Risk_Level
# 0.0                                                           128951
# 1.0                                                             7755
# 2.0                                                             7388
# 3.0                                                             8647
# 4.0                                                             2528
# 5.0                                                              513
#
#                        OFFENSE_CLEAN_ARMED ROBBERY  \
# Recidivate_Risk_Level
# 0.0                                         128951
# 1.0                                           7755
# 2.0                                           7388
# 3.0                                           8647
# 4.0                                           2528
# 5.0                                            513
#
#                        OFFENSE_CLEAN_ASSAULT BY STRANGULATION  \
# Recidivate_Risk_Level
# 0.0                                                    128951
# 1.0                                                      7755
# 2.0                                                      7388
# 3.0                                                      8647
# 4.0                                                      2528
# 5.0                                                       513
#
#                        OFFENSE_CLEAN_ASSAULT INFLICT SERI BODY INJ  \
# Recidivate_Risk_Level
# 0.0                                                         128951
# 1.0                                                           7755
# 2.0                                                           7388
# 3.0                                                           8647
# 4.0                                                           2528
# 5.0                                                            513
#
#                        OFFENSE_CLEAN_ASSAULT ISI  \
# Recidivate_Risk_Level
# 0.0                                       128951
# 1.0                                         7755
# 2.0                                         7388
# 3.0                                         8647
# 4.0                                         2528
# 5.0                                          513
#
#                        OFFENSE_CLEAN_ASSAULT ON FEMALE  \
# Recidivate_Risk_Level
# 0.0                                             128951
# 1.0                                               7755
# 2.0                                               7388
# 3.0                                               8647
# 4.0                                               2528
# 5.0                                                513
#
#                        OFFENSE_CLEAN_ASSAULT ON OFFICER/ST EMPLOYEE  \
# Recidivate_Risk_Level
# 0.0                                                          128951
# 1.0                                                            7755
# 2.0                                                            7388
# 3.0                                                            8647
# 4.0                                                            2528
# 5.0                                                             513
#
#                        OFFENSE_CLEAN_ASSAULT ON POLICEMAN  \
# Recidivate_Risk_Level
# 0.0                                                128951
# 1.0                                                  7755
# 2.0                                                  7388
# 3.0                                                  8647
# 4.0                                                  2528
# 5.0                                                   513
#
#                        OFFENSE_CLEAN_ASSAULT ON PUBLIC OFFICIAL  \
# Recidivate_Risk_Level
# 0.0                                                      128951
# 1.0                                                        7755
# 2.0                                                        7388
# 3.0                                                        8647
# 4.0                                                        2528
# 5.0                                                         513
#
#                        OFFENSE_CLEAN_AWDW  \
# Recidivate_Risk_Level
# 0.0                                128951
# 1.0                                  7755
# 2.0                                  7388
# 3.0                                  8647
# 4.0                                  2528
# 5.0                                   513
#
#                        OFFENSE_CLEAN_AWDW GOV OFFICERS/EMPLOYEES  \
# Recidivate_Risk_Level
# 0.0                                                       128951
# 1.0                                                         7755
# 2.0                                                         7388
# 3.0                                                         8647
# 4.0                                                         2528
# 5.0                                                          513
#
#                        OFFENSE_CLEAN_AWDWISI  OFFENSE_CLEAN_AWDWWITKISI  \
# Recidivate_Risk_Level
# 0.0                                   128951                     128951
# 1.0                                     7755                       7755
# 2.0                                     7388                       7388
# 3.0                                     8647                       8647
# 4.0                                     2528                       2528
# 5.0                                      513                        513
#
#                        OFFENSE_CLEAN_B & E & L  OFFENSE_CLEAN_B & E VEHICLES  \
# Recidivate_Risk_Level
# 0.0                                     128951                        128951
# 1.0                                       7755                          7755
# 2.0                                       7388                          7388
# 3.0                                       8647                          8647
# 4.0                                       2528                          2528
# 5.0                                        513                           513
#
#                        OFFENSE_CLEAN_BURGLARY 1ST DEGREE  \
# Recidivate_Risk_Level
# 0.0                                               128951
# 1.0                                                 7755
# 2.0                                                 7388
# 3.0                                                 8647
# 4.0                                                 2528
# 5.0                                                  513
#
#                        OFFENSE_CLEAN_BURGLARY 2ND DEGREE  \
# Recidivate_Risk_Level
# 0.0                                               128951
# 1.0                                                 7755
# 2.0                                                 7388
# 3.0                                                 8647
# 4.0                                                 2528
# 5.0                                                  513
#
#                        OFFENSE_CLEAN_CHEAT - PROPERTY/SERVICES  \
# Recidivate_Risk_Level
# 0.0                                                     128951
# 1.0                                                       7755
# 2.0                                                       7388
# 3.0                                                       8647
# 4.0                                                       2528
# 5.0                                                        513
#
#                        OFFENSE_CLEAN_COMMON LAW FORGERY  \
# Recidivate_Risk_Level
# 0.0                                              128951
# 1.0                                                7755
# 2.0                                                7388
# 3.0                                                8647
# 4.0                                                2528
# 5.0                                                 513
#
#                        OFFENSE_CLEAN_COMMON LAW ROBBERY  \
# Recidivate_Risk_Level
# 0.0                                              128951
# 1.0                                                7755
# 2.0                                                7388
# 3.0                                                8647
# 4.0                                                2528
# 5.0                                                 513
#
#                        OFFENSE_CLEAN_COMMUNICATING THREATS  \
# Recidivate_Risk_Level
# 0.0                                                 128951
# 1.0                                                   7755
# 2.0                                                   7388
# 3.0                                                   8647
# 4.0                                                   2528
# 5.0                                                    513
#
#                        OFFENSE_CLEAN_CREDIT CARD THEFT  \
# Recidivate_Risk_Level
# 0.0                                             128951
# 1.0                                               7755
# 2.0                                               7388
# 3.0                                               8647
# 4.0                                               2528
# 5.0                                                513
#
#                        OFFENSE_CLEAN_DAMAGE TO PROPERTY  \
# Recidivate_Risk_Level
# 0.0                                              128951
# 1.0                                                7755
# 2.0                                                7388
# 3.0                                                8647
# 4.0                                                2528
# 5.0                                                 513
#
#                        OFFENSE_CLEAN_DEL/SELL SCHEDULE II  \
# Recidivate_Risk_Level
# 0.0                                                128951
# 1.0                                                  7755
# 2.0                                                  7388
# 3.0                                                  8647
# 4.0                                                  2528
# 5.0                                                   513
#
#                        OFFENSE_CLEAN_DISCHG FIREARM-OCC PROPERTY  \
# Recidivate_Risk_Level
# 0.0                                                       128951
# 1.0                                                         7755
# 2.0                                                         7388
# 3.0                                                         8647
# 4.0                                                         2528
# 5.0                                                          513
#
#                        OFFENSE_CLEAN_DRIV LICENSE PERM RVK  \
# Recidivate_Risk_Level
# 0.0                                                 128951
# 1.0                                                   7755
# 2.0                                                   7388
# 3.0                                                   8647
# 4.0                                                   2528
# 5.0                                                    513
#
#                        OFFENSE_CLEAN_DRIV LICENSE REVOKED  \
# Recidivate_Risk_Level
# 0.0                                                128951
# 1.0                                                  7755
# 2.0                                                  7388
# 3.0                                                  8647
# 4.0                                                  2528
# 5.0                                                   513
#
#                        OFFENSE_CLEAN_DRIVING UNDER INFLUENCE (DUI)  \
# Recidivate_Risk_Level
# 0.0                                                         128951
# 1.0                                                           7755
# 2.0                                                           7388
# 3.0                                                           8647
# 4.0                                                           2528
# 5.0                                                            513
#
#                        OFFENSE_CLEAN_DRUG PARA - USE/POSSESS  \
# Recidivate_Risk_Level
# 0.0                                                   128951
# 1.0                                                     7755
# 2.0                                                     7388
# 3.0                                                     8647
# 4.0                                                     2528
# 5.0                                                      513
#
#                        OFFENSE_CLEAN_DWI DRIVING WHILE IMPAIRED  \
# Recidivate_Risk_Level
# 0.0                                                      128951
# 1.0                                                        7755
# 2.0                                                        7388
# 3.0                                                        8647
# 4.0                                                        2528
# 5.0                                                         513
#
#                        OFFENSE_CLEAN_DWI LEVEL 1  \
# Recidivate_Risk_Level
# 0.0                                       128951
# 1.0                                         7755
# 2.0                                         7388
# 3.0                                         8647
# 4.0                                         2528
# 5.0                                          513
#
#                        OFFENSE_CLEAN_DWI LEVEL 1 AGGRAVATED  \
# Recidivate_Risk_Level
# 0.0                                                  128951
# 1.0                                                    7755
# 2.0                                                    7388
# 3.0                                                    8647
# 4.0                                                    2528
# 5.0                                                     513
#
#                        OFFENSE_CLEAN_DWI LEVEL 2  OFFENSE_CLEAN_DWI LEVEL 3  \
# Recidivate_Risk_Level
# 0.0                                       128951                     128951
# 1.0                                         7755                       7755
# 2.0                                         7388                       7388
# 3.0                                         8647                       8647
# 4.0                                         2528                       2528
# 5.0                                          513                        513
#
#                        OFFENSE_CLEAN_DWI LEVEL 4  OFFENSE_CLEAN_DWI LEVEL 5  \
# Recidivate_Risk_Level
# 0.0                                       128951                     128951
# 1.0                                         7755                       7755
# 2.0                                         7388                       7388
# 3.0                                         8647                       8647
# 4.0                                         2528                       2528
# 5.0                                          513                        513
#
#                        OFFENSE_CLEAN_EMBEZZLEMENT  \
# Recidivate_Risk_Level
# 0.0                                        128951
# 1.0                                          7755
# 2.0                                          7388
# 3.0                                          8647
# 4.0                                          2528
# 5.0                                           513
#
#                        OFFENSE_CLEAN_FAIL TO REGISTER (SEX OFFENDER  \
# Recidivate_Risk_Level
# 0.0                                                          128951
# 1.0                                                            7755
# 2.0                                                            7388
# 3.0                                                            8647
# 4.0                                                            2528
# 5.0                                                             513
#
#                        OFFENSE_CLEAN_FELONY B&E  OFFENSE_CLEAN_FORGERY  \
# Recidivate_Risk_Level
# 0.0                                      128951                 128951
# 1.0                                        7755                   7755
# 2.0                                        7388                   7388
# 3.0                                        8647                   8647
# 4.0                                        2528                   2528
# 5.0                                         513                    513
#
#                        OFFENSE_CLEAN_HABITUAL FELON  \
# Recidivate_Risk_Level
# 0.0                                          128951
# 1.0                                            7755
# 2.0                                            7388
# 3.0                                            8647
# 4.0                                            2528
# 5.0                                             513
#
#                        OFFENSE_CLEAN_HABITUAL IMPAIRED DRIVING  \
# Recidivate_Risk_Level
# 0.0                                                     128951
# 1.0                                                       7755
# 2.0                                                       7388
# 3.0                                                       8647
# 4.0                                                       2528
# 5.0                                                        513
#
#                        OFFENSE_CLEAN_HABITUAL MISDEMEANOR ASSAULT  \
# Recidivate_Risk_Level
# 0.0                                                        128951
# 1.0                                                          7755
# 2.0                                                          7388
# 3.0                                                          8647
# 4.0                                                          2528
# 5.0                                                           513
#
#                        OFFENSE_CLEAN_IDENTITY FRAUD/THEFT  \
# Recidivate_Risk_Level
# 0.0                                                128951
# 1.0                                                  7755
# 2.0                                                  7388
# 3.0                                                  8647
# 4.0                                                  2528
# 5.0                                                   513
#
#                        OFFENSE_CLEAN_INDECENT LIBERTY W/CHILD  \
# Recidivate_Risk_Level
# 0.0                                                    128951
# 1.0                                                      7755
# 2.0                                                      7388
# 3.0                                                      8647
# 4.0                                                      2528
# 5.0                                                       513
#
#                        OFFENSE_CLEAN_INVOLUNTARY MANSLAUGHTER  \
# Recidivate_Risk_Level
# 0.0                                                    128951
# 1.0                                                      7755
# 2.0                                                      7388
# 3.0                                                      8647
# 4.0                                                      2528
# 5.0                                                       513
#
#                        OFFENSE_CLEAN_KIDNAPPING 2ND DEGREE  \
# Recidivate_Risk_Level
# 0.0                                                 128951
# 1.0                                                   7755
# 2.0                                                   7388
# 3.0                                                   8647
# 4.0                                                   2528
# 5.0                                                    513
#
#                        OFFENSE_CLEAN_LARCENY  \
# Recidivate_Risk_Level
# 0.0                                   128951
# 1.0                                     7755
# 2.0                                     7388
# 3.0                                     8647
# 4.0                                     2528
# 5.0                                      513
#
#                        OFFENSE_CLEAN_LARCENY (OVER $200)  \
# Recidivate_Risk_Level
# 0.0                                               128951
# 1.0                                                 7755
# 2.0                                                 7388
# 3.0                                                 8647
# 4.0                                                 2528
# 5.0                                                  513
#
#                        OFFENSE_CLEAN_LARCENY AFTER B & E  \
# Recidivate_Risk_Level
# 0.0                                               128951
# 1.0                                                 7755
# 2.0                                                 7388
# 3.0                                                 8647
# 4.0                                                 2528
# 5.0                                                  513
#
#                        OFFENSE_CLEAN_LARCENY BY SERVANT/EMPLOYEE  \
# Recidivate_Risk_Level
# 0.0                                                       128951
# 1.0                                                         7755
# 2.0                                                         7388
# 3.0                                                         8647
# 4.0                                                         2528
# 5.0                                                          513
#
#                        OFFENSE_CLEAN_LARCENY FROM PERSON  \
# Recidivate_Risk_Level
# 0.0                                               128951
# 1.0                                                 7755
# 2.0                                                 7388
# 3.0                                                 8647
# 4.0                                                 2528
# 5.0                                                  513
#
#                        OFFENSE_CLEAN_LARCENY OF FIREARMS  \
# Recidivate_Risk_Level
# 0.0                                               128951
# 1.0                                                 7755
# 2.0                                                 7388
# 3.0                                                 8647
# 4.0                                                 2528
# 5.0                                                  513
#
#                        OFFENSE_CLEAN_LARCENY OF MOTOR VEHICLE  \
# Recidivate_Risk_Level
# 0.0                                                    128951
# 1.0                                                      7755
# 2.0                                                      7388
# 3.0                                                      8647
# 4.0                                                      2528
# 5.0                                                       513
#
#                        OFFENSE_CLEAN_LARCENY OVER $1000  \
# Recidivate_Risk_Level
# 0.0                                              128951
# 1.0                                                7755
# 2.0                                                7388
# 3.0                                                8647
# 4.0                                                2528
# 5.0                                                 513
#
#                        OFFENSE_CLEAN_MAINT ANY PLACE CONTR SUB  \
# Recidivate_Risk_Level
# 0.0                                                     128951
# 1.0                                                       7755
# 2.0                                                       7388
# 3.0                                                       8647
# 4.0                                                       2528
# 5.0                                                        513
#
#                        OFFENSE_CLEAN_MANSLAUGHTER  OFFENSE_CLEAN_MISD B&E  \
# Recidivate_Risk_Level
# 0.0                                        128951                  128951
# 1.0                                          7755                    7755
# 2.0                                          7388                    7388
# 3.0                                          8647                    8647
# 4.0                                          2528                    2528
# 5.0                                           513                     513
#
#                        OFFENSE_CLEAN_MURDER FIRST DEGREE  \
# Recidivate_Risk_Level
# 0.0                                               128951
# 1.0                                                 7755
# 2.0                                                 7388
# 3.0                                                 8647
# 4.0                                                 2528
# 5.0                                                  513
#
#                        OFFENSE_CLEAN_MURDER SECOND DEGREE  \
# Recidivate_Risk_Level
# 0.0                                                128951
# 1.0                                                  7755
# 2.0                                                  7388
# 3.0                                                  8647
# 4.0                                                  2528
# 5.0                                                   513
#
#                        OFFENSE_CLEAN_NON-SUPPORT  \
# Recidivate_Risk_Level
# 0.0                                       128951
# 1.0                                         7755
# 2.0                                         7388
# 3.0                                         8647
# 4.0                                         2528
# 5.0                                          513
#
#                        OFFENSE_CLEAN_OBT PROP BY FALSE PR/CHTS/SER  \
# Recidivate_Risk_Level
# 0.0                                                         128951
# 1.0                                                           7755
# 2.0                                                           7388
# 3.0                                                           8647
# 4.0                                                           2528
# 5.0                                                            513
#
#                        OFFENSE_CLEAN_OPERATE VEHICLE W/O LICENSE  \
# Recidivate_Risk_Level
# 0.0                                                       128951
# 1.0                                                         7755
# 2.0                                                         7388
# 3.0                                                         8647
# 4.0                                                         2528
# 5.0                                                          513
#
#                        OFFENSE_CLEAN_OTHER  OFFENSE_CLEAN_POSSESS SCHEDULE I  \
# Recidivate_Risk_Level
# 0.0                                 128951                            128951
# 1.0                                   7755                              7755
# 2.0                                   7388                              7388
# 3.0                                   8647                              8647
# 4.0                                   2528                              2528
# 5.0                                    513                               513
#
#                        OFFENSE_CLEAN_POSSESS SCHEDULE II  \
# Recidivate_Risk_Level
# 0.0                                               128951
# 1.0                                                 7755
# 2.0                                                 7388
# 3.0                                                 8647
# 4.0                                                 2528
# 5.0                                                  513
#
#                        OFFENSE_CLEAN_POSSESS SCHEDULE VI  \
# Recidivate_Risk_Level
# 0.0                                               128951
# 1.0                                                 7755
# 2.0                                                 7388
# 3.0                                                 8647
# 4.0                                                 2528
# 5.0                                                  513
#
#                        OFFENSE_CLEAN_POSSESS WITS SCHEDULE I  \
# Recidivate_Risk_Level
# 0.0                                                   128951
# 1.0                                                     7755
# 2.0                                                     7388
# 3.0                                                     8647
# 4.0                                                     2528
# 5.0                                                      513
#
#                        OFFENSE_CLEAN_POSSESS WITS SCHEDULE II  \
# Recidivate_Risk_Level
# 0.0                                                    128951
# 1.0                                                      7755
# 2.0                                                      7388
# 3.0                                                      8647
# 4.0                                                      2528
# 5.0                                                       513
#
#                        OFFENSE_CLEAN_POSSESS WITS SCHEDULE VI  \
# Recidivate_Risk_Level
# 0.0                                                    128951
# 1.0                                                      7755
# 2.0                                                      7388
# 3.0                                                      8647
# 4.0                                                      2528
# 5.0                                                       513
#
#                        OFFENSE_CLEAN_POSSESSING STOLEN GOODS  \
# Recidivate_Risk_Level
# 0.0                                                   128951
# 1.0                                                     7755
# 2.0                                                     7388
# 3.0                                                     8647
# 4.0                                                     2528
# 5.0                                                      513
#
#                        OFFENSE_CLEAN_POSSESSION OF FIREARM BY FELON  \
# Recidivate_Risk_Level
# 0.0                                                          128951
# 1.0                                                            7755
# 2.0                                                            7388
# 3.0                                                            8647
# 4.0                                                            2528
# 5.0                                                             513
#
#                        OFFENSE_CLEAN_RAPE FIRST DEGREE  \
# Recidivate_Risk_Level
# 0.0                                             128951
# 1.0                                               7755
# 2.0                                               7388
# 3.0                                               8647
# 4.0                                               2528
# 5.0                                                513
#
#                        OFFENSE_CLEAN_RAPE SECOND DEGREE  \
# Recidivate_Risk_Level
# 0.0                                              128951
# 1.0                                                7755
# 2.0                                                7388
# 3.0                                                8647
# 4.0                                                2528
# 5.0                                                 513
#
#                        OFFENSE_CLEAN_RECEIVING STOLEN GOODS  \
# Recidivate_Risk_Level
# 0.0                                                  128951
# 1.0                                                    7755
# 2.0                                                    7388
# 3.0                                                    8647
# 4.0                                                    2528
# 5.0                                                     513
#
#                        OFFENSE_CLEAN_RECEIVING STOLEN VEHICLE  \
# Recidivate_Risk_Level
# 0.0                                                    128951
# 1.0                                                      7755
# 2.0                                                      7388
# 3.0                                                      8647
# 4.0                                                      2528
# 5.0                                                       513
#
#                        OFFENSE_CLEAN_RESISTING OFFICER  \
# Recidivate_Risk_Level
# 0.0                                             128951
# 1.0                                               7755
# 2.0                                               7388
# 3.0                                               8647
# 4.0                                               2528
# 5.0                                                513
#
#                        OFFENSE_CLEAN_ROBBERY W/DANGEROUS WEAPON  \
# Recidivate_Risk_Level
# 0.0                                                      128951
# 1.0                                                        7755
# 2.0                                                        7388
# 3.0                                                        8647
# ...
# 2.0                                  7388                7388
# 3.0                                  8647                8647
# 4.0                                  2528                2528
# 5.0                                   513                 513
#
#                        year_month_2016-02  year_month_2016-03  \
# Recidivate_Risk_Level
# 0.0                                128951              128951
# 1.0                                  7755                7755
# 2.0                                  7388                7388
# 3.0                                  8647                8647
# 4.0                                  2528                2528
# 5.0                                   513                 513
#
#                        year_month_2016-04  year_month_2016-05  \
# Recidivate_Risk_Level
# 0.0                                128951              128951
# 1.0                                  7755                7755
# 2.0                                  7388                7388
# 3.0                                  8647                8647
# 4.0                                  2528                2528
# 5.0                                   513                 513
#
#                        year_month_2016-06  year_month_2016-07  \
# Recidivate_Risk_Level
# 0.0                                128951              128951
# 1.0                                  7755                7755
# 2.0                                  7388                7388
# 3.0                                  8647                8647
# 4.0                                  2528                2528
# 5.0                                   513                 513
#
#                        year_month_2016-08  year_month_2016-09  \
# Recidivate_Risk_Level
# 0.0                                128951              128951
# 1.0                                  7755                7755
# 2.0                                  7388                7388
# 3.0                                  8647                8647
# 4.0                                  2528                2528
# 5.0                                   513                 513
#
#                        year_month_2016-10  year_month_2016-11  \
# Recidivate_Risk_Level
# 0.0                                128951              128951
# 1.0                                  7755                7755
# 2.0                                  7388                7388
# 3.0                                  8647                8647
# 4.0                                  2528                2528
# 5.0                                   513                 513
#
#                        year_month_2016-12  year_month_2017-01  \
# Recidivate_Risk_Level
# 0.0                                128951              128951
# 1.0                                  7755                7755
# 2.0                                  7388                7388
# 3.0                                  8647                8647
# 4.0                                  2528                2528
# 5.0                                   513                 513
#
#                        year_month_2017-02  year_month_2017-03  \
# Recidivate_Risk_Level
# 0.0                                128951              128951
# 1.0                                  7755                7755
# 2.0                                  7388                7388
# 3.0                                  8647                8647
# 4.0                                  2528                2528
# 5.0                                   513                 513
#
#                        year_month_2017-04  year_month_2017-05  \
# Recidivate_Risk_Level
# 0.0                                128951              128951
# 1.0                                  7755                7755
# 2.0                                  7388                7388
# 3.0                                  8647                8647
# 4.0                                  2528                2528
# 5.0                                   513                 513
#
#                        year_month_2017-06  year_month_2017-07  \
# Recidivate_Risk_Level
# 0.0                                128951              128951
# 1.0                                  7755                7755
# 2.0                                  7388                7388
# 3.0                                  8647                8647
# 4.0                                  2528                2528
# 5.0                                   513                 513
#
#                        year_month_2017-08  year_month_2017-09  \
# Recidivate_Risk_Level
# 0.0                                128951              128951
# 1.0                                  7755                7755
# 2.0                                  7388                7388
# 3.0                                  8647                8647
# 4.0                                  2528                2528
# 5.0                                   513                 513
#
#                        year_month_2017-10  year_month_2017-11  \
# Recidivate_Risk_Level
# 0.0                                128951              128951
# 1.0                                  7755                7755
# 2.0                                  7388                7388
# 3.0                                  8647                8647
# 4.0                                  2528                2528
# 5.0                                   513                 513
#
#                        year_month_2017-12  year_month_2018-01  \
# Recidivate_Risk_Level
# 0.0                                128951              128951
# 1.0                                  7755                7755
# 2.0                                  7388                7388
# 3.0                                  8647                8647
# 4.0                                  2528                2528
# 5.0                                   513                 513
#
#                        year_month_2018-02  year_month_2018-03  \
# Recidivate_Risk_Level
# 0.0                                128951              128951
# 1.0                                  7755                7755
# 2.0                                  7388                7388
# 3.0                                  8647                8647
# 4.0                                  2528                2528
# 5.0                                   513                 513
#
#                        year_month_2018-04  year_month_2018-05  \
# Recidivate_Risk_Level
# 0.0                                128951              128951
# 1.0                                  7755                7755
# 2.0                                  7388                7388
# 3.0                                  8647                8647
# 4.0                                  2528                2528
# 5.0                                   513                 513
#
#                        year_month_2018-06  year_month_2018-07  \
# Recidivate_Risk_Level
# 0.0                                128951              128951
# 1.0                                  7755                7755
# 2.0                                  7388                7388
# 3.0                                  8647                8647
# 4.0                                  2528                2528
# 5.0                                   513                 513
#
#                        year_month_2018-08  year_month_2018-09  \
# Recidivate_Risk_Level
# 0.0                                128951              128951
# 1.0                                  7755                7755
# 2.0                                  7388                7388
# 3.0                                  8647                8647
# 4.0                                  2528                2528
# 5.0                                   513                 513
#
#                        year_month_2018-10  year_month_2018-11  \
# Recidivate_Risk_Level
# 0.0                                128951              128951
# 1.0                                  7755                7755
# 2.0                                  7388                7388
# 3.0                                  8647                8647
# 4.0                                  2528                2528
# 5.0                                   513                 513
#
#                        year_month_2018-12  year_month_2019-01  \
# Recidivate_Risk_Level
# 0.0                                128951              128951
# 1.0                                  7755                7755
# 2.0                                  7388                7388
# 3.0                                  8647                8647
# 4.0                                  2528                2528
# 5.0                                   513                 513
#
#                        year_month_2019-02  year_month_2019-03  \
# Recidivate_Risk_Level
# 0.0                                128951              128951
# 1.0                                  7755                7755
# 2.0                                  7388                7388
# 3.0                                  8647                8647
# 4.0                                  2528                2528
# 5.0                                   513                 513
#
#                        year_month_2019-04  year_month_2019-05  \
# Recidivate_Risk_Level
# 0.0                                128951              128951
# 1.0                                  7755                7755
# 2.0                                  7388                7388
# 3.0                                  8647                8647
# 4.0                                  2528                2528
# 5.0                                   513                 513
#
#                        year_month_2019-06  year_month_2019-07  \
# Recidivate_Risk_Level
# 0.0                                128951              128951
# 1.0                                  7755                7755
# 2.0                                  7388                7388
# 3.0                                  8647                8647
# 4.0                                  2528                2528
# 5.0                                   513                 513
#
#                        year_month_2019-08  year_month_2019-09  \
# Recidivate_Risk_Level
# 0.0                                128951              128951
# 1.0                                  7755                7755
# 2.0                                  7388                7388
# 3.0                                  8647                8647
# 4.0                                  2528                2528
# 5.0                                   513                 513
#
#                        year_month_2019-10  year_month_2019-11  \
# Recidivate_Risk_Level
# 0.0                                128951              128951
# 1.0                                  7755                7755
# 2.0                                  7388                7388
# 3.0                                  8647                8647
# 4.0                                  2528                2528
# 5.0                                   513                 513
#
#                        year_month_2019-12  year_month_2020-01  \
# Recidivate_Risk_Level
# 0.0                                128951              128951
# 1.0                                  7755                7755
# 2.0                                  7388                7388
# 3.0                                  8647                8647
# 4.0                                  2528                2528
# 5.0                                   513                 513
#
#                        year_month_2020-02  year_month_2020-03  \
# Recidivate_Risk_Level
# 0.0                                128951              128951
# 1.0                                  7755                7755
# 2.0                                  7388                7388
# 3.0                                  8647                8647
# 4.0                                  2528                2528
# 5.0                                   513                 513
#
#                        year_month_2020-04  age_cat_Under 18  age_cat_18-21  \
# Recidivate_Risk_Level
# 0.0                                128951            128951         128951
# 1.0                                  7755              7755           7755
# 2.0                                  7388              7388           7388
# 3.0                                  8647              8647           8647
# 4.0                                  2528              2528           2528
# 5.0                                   513               513            513
#
#                        age_cat_22-24  age_cat_25-29  age_cat_30-34  \
# Recidivate_Risk_Level
# 0.0                           128951         128951         128951
# 1.0                             7755           7755           7755
# 2.0                             7388           7388           7388
# 3.0                             8647           8647           8647
# 4.0                             2528           2528           2528
# 5.0                              513            513            513
#
#                        age_cat_35-39  age_cat_40-44  age_cat_45-49  \
# Recidivate_Risk_Level
# 0.0                           128951         128951         128951
# 1.0                             7755           7755           7755
# 2.0                             7388           7388           7388
# 3.0                             8647           8647           8647
# 4.0                             2528           2528           2528
# 5.0                              513            513            513
#
#                        age_cat_50-54  age_cat_55-59  age_cat_60-64  \
# Recidivate_Risk_Level
# 0.0                           128951         128951         128951
# 1.0                             7755           7755           7755
# 2.0                             7388           7388           7388
# 3.0                             8647           8647           8647
# 4.0                             2528           2528           2528
# 5.0                              513            513            513
#
#                        age_cat_65 and older
# Recidivate_Risk_Level
# 0.0                                  128951
# 1.0                                    7755
# 2.0                                    7388
# 3.0                                    8647
# 4.0                                    2528
# 5.0                                     513

# %%
test_predict = model.predict(test_data.loc[:,test_data.columns!=target])

# %%
print("Accuracy:\t{}\nPrecision:\t{}\nRecall:\t\t{}\nF1 Score:\t{}\n".format(accuracy_score(test_data[target], test_predict),
                                                                           precision_score(test_data[target], test_predict,average=None),
                                                                           recall_score(test_data[target], test_predict,average=None),
                                                                           f1_score(test_data[target], test_predict,average=None)
                                                                          ))
# Out:
# Accuracy:	0.8275217932752179
# Precision:	[0.82893432 0.34375    0.36981132 0.10638298 0.25       0.        ]
# Recall:		[9.98557592e-01 5.67375887e-03 1.32647537e-02 5.78235226e-04
#  3.95569620e-04 0.00000000e+00]
# F1 Score:	[9.05873952e-01 1.11632627e-02 2.56108716e-02 1.15021854e-03
#  7.89889415e-04 0.00000000e+00]
# /Users/daminisharma/miniconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
