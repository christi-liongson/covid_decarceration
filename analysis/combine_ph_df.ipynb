# %%
# %load_ext autoreload
# %autoreload 2

from build_prison_conditions_df import build_prison_conditions_df
import clean_data
import pandas as pd

# %%
df = build_prison_conditions_df()
df.replace('federal bop', 'federal', inplace=True)

# %%
MARSHALL_CSV = '../data/marshall_covid_cases.csv'

marshall_dtypes = {'name': str,
                   'total_staff_cases': 'Int64',
                   'total_prisoner_cases': 'Int64',
                   'total_staff_deaths': 'Int64',
                   'total_prisoner_deaths': 'Int64',
                   'as_of_date': str}

marshall = clean_data.import_csv(MARSHALL_CSV, marshall_dtypes)

marshall['as_of_date'] = pd.to_datetime(marshall['as_of_date'], format='%Y-%m-%d')
marshall['lower_name'] = marshall['name'].str.lower()

marshall.sort_values(by='as_of_date', inplace=True)

for state in list(marshall['name'].unique()):
    state_filter = marshall['name'] == state
    for col in marshall.select_dtypes(include='number').columns.to_list():
        marshall.loc[state_filter, col] = marshall.loc[state_filter, col].fillna(method='bfill')
        marshall.loc[state_filter, col] = marshall.loc[state_filter, col].fillna(method='ffill')

state_policies = marshall.merge(df[demographics], left_on='lower_name', right_on='state')
# Out:
# ['name', 'total_staff_cases', 'total_prisoner_cases', 'total_staff_deaths', 'total_prisoner_deaths', 'as_of_date']

# %%
state_policies
# Out:
#             name  total_staff_cases  total_prisoner_cases  total_staff_deaths  \
# 0       Delaware                  0                     0                   0
# 1       Delaware                  0                     0                   0
# 2       Delaware                  6                     2                   0
# 3       Delaware                 18                    13                   0
# 4       Delaware                 26                    41                   0
# ..           ...                ...                   ...                 ...
# 454  Connecticut                244                   321                   0
# 455  Connecticut                326                   417                   0
# 456  Connecticut                358                   478                   0
# 457  Connecticut                368                   526                   0
# 458  Connecticut                373                   684                   0
#
#      total_prisoner_deaths as_of_date   lower_name        state  pop_2020  \
# 0                        0 2020-03-24     delaware     delaware    5582.0
# 1                        0 2020-04-01     delaware     delaware    5582.0
# 2                        0 2020-04-08     delaware     delaware    5582.0
# 3                        0 2020-04-15     delaware     delaware    5582.0
# 4                        1 2020-04-22     delaware     delaware    5582.0
# ..                     ...        ...          ...          ...       ...
# 454                      1 2020-04-22  connecticut  connecticut   13228.0
# 455                      3 2020-04-29  connecticut  connecticut   13228.0
# 456                      6 2020-05-06  connecticut  connecticut   13228.0
# 457                      6 2020-05-13  connecticut  connecticut   13228.0
# 458                      6 2020-05-20  connecticut  connecticut   13228.0
#
#      pop_2018  capacity  pct_occup
# 0      5582.0    5566.0   1.002875
# 1      5582.0    5566.0   1.002875
# 2      5582.0    5566.0   1.002875
# 3      5582.0    5566.0   1.002875
# 4      5582.0    5566.0   1.002875
# ..        ...       ...        ...
# 454   13228.0   13228.0   1.000000
# 455   13228.0   13228.0   1.000000
# 456   13228.0   13228.0   1.000000
# 457   13228.0   13228.0   1.000000
# 458   13228.0   13228.0   1.000000
#
# [459 rows x 12 columns]

# %%
for _, row in state_policies.iterrows():
    print(row)
# Out:
#              oregon
# pop_2020                               14707
# pop_2018                               14707
# capacity                               15612
# pct_occup                           0.942032
# Name: 423, dtype: object
# name                                  Oregon
# total_staff_cases                          1
# total_prisoner_cases                       0
# total_staff_deaths                         0
# total_prisoner_deaths                      0
# as_of_date               2020-04-01 00:00:00
# lower_name                            oregon
# state                                 oregon
# pop_2020                               14707
# pop_2018                               14707
# capacity                               15612
# pct_occup                           0.942032
# Name: 424, dtype: object
# name                                  Oregon
# total_staff_cases                          5
# total_prisoner_cases                       3
# total_staff_deaths                         0
# total_prisoner_deaths                      0
# as_of_date               2020-04-08 00:00:00
# lower_name                            oregon
# state                                 oregon
# pop_2020                               14707
# pop_2018                               14707
# capacity                               15612
# pct_occup                           0.942032
# Name: 425, dtype: object
# name                                  Oregon
# total_staff_cases                         10
# total_prisoner_cases                       5
# total_staff_deaths                         0
# total_prisoner_deaths                      0
# as_of_date               2020-04-15 00:00:00
# lower_name                            oregon
# state                                 oregon
# pop_2020                               14707
# pop_2018                               14707
# capacity                               15612
# pct_occup                           0.942032
# Name: 426, dtype: object
# name                                  Oregon
# total_staff_cases                         10
# total_prisoner_cases                       7
# total_staff_deaths                         0
# total_prisoner_deaths                      0
# as_of_date               2020-04-22 00:00:00
# lower_name                            oregon
# state                                 oregon
# pop_2020                               14707
# pop_2018                               14707
# capacity                               15612
# pct_occup                           0.942032
# Name: 427, dtype: object
# name                                  Oregon
# total_staff_cases                         15
# total_prisoner_cases                      21
# total_staff_deaths                         0
# total_prisoner_deaths                      0
# as_of_date               2020-04-29 00:00:00
# lower_name                            oregon
# state                                 oregon
# pop_2020                               14707
# pop_2018                               14707
# capacity                               15612
# pct_occup                           0.942032
# Name: 428, dtype: object
# name                                  Oregon
# total_staff_cases                         21
# total_prisoner_cases                      44
# total_staff_deaths                         0
# total_prisoner_deaths                      0
# as_of_date               2020-05-06 00:00:00
# lower_name                            oregon
# state                                 oregon
# pop_2020                               14707
# pop_2018                               14707
# capacity                               15612
# pct_occup                           0.942032
# Name: 429, dtype: object
# name                                  Oregon
# total_staff_cases                         32
# total_prisoner_cases                     113
# total_staff_deaths                         0
# total_prisoner_deaths                      0
# as_of_date               2020-05-13 00:00:00
# lower_name                            oregon
# state                                 oregon
# pop_2020                               14707
# pop_2018                               14707
# capacity                               15612
# pct_occup                           0.942032
# Name: 430, dtype: object
# name                                  Oregon
# total_staff_cases                         38
# total_prisoner_cases                     143
# total_staff_deaths                         0
# total_prisoner_deaths                      1
# as_of_date               2020-05-21 00:00:00
# lower_name                            oregon
# state                                 oregon
# pop_2020                               14707
# pop_2018                               14707
# capacity                               15612
# pct_occup                           0.942032
# Name: 431, dtype: object
# name                            Pennsylvania
# total_staff_cases                          8
# total_prisoner_cases                       0
# total_staff_deaths                         0
# total_prisoner_deaths                      0
# as_of_date               2020-03-26 00:00:00
# lower_name                      pennsylvania
# state                           pennsylvania
# pop_2020                               44500
# pop_2018                               45941
# capacity                               48961
# pct_occup                           0.938318
# Name: 432, dtype: object
# name                            Pennsylvania
# total_staff_cases                          8
# total_prisoner_cases                       2
# total_staff_deaths                         0
# total_prisoner_deaths                      0
# as_of_date               2020-04-01 00:00:00
# lower_name                      pennsylvania
# state                           pennsylvania
# pop_2020                               44500
# pop_2018                               45941
# capacity                               48961
# pct_occup                           0.938318
# Name: 433, dtype: object
# name                            Pennsylvania
# total_staff_cases                         16
# total_prisoner_cases                       7
# total_staff_deaths                         0
# total_prisoner_deaths                      0
# as_of_date               2020-04-08 00:00:00
# lower_name                      pennsylvania
# state                           pennsylvania
# pop_2020                               44500
# pop_2018                               45941
# capacity                               48961
# pct_occup                           0.938318
# Name: 434, dtype: object
# name                            Pennsylvania
# total_staff_cases                         24
# total_prisoner_cases                      17
# total_staff_deaths                         0
# total_prisoner_deaths                      1
# as_of_date               2020-04-15 00:00:00
# lower_name                      pennsylvania
# state                           pennsylvania
# pop_2020                               44500
# pop_2018                               45941
# capacity                               48961
# pct_occup                           0.938318
# Name: 435, dtype: object
# name                            Pennsylvania
# total_staff_cases                         54
# total_prisoner_cases                      29
# total_staff_deaths                         0
# total_prisoner_deaths                      1
# as_of_date               2020-04-22 00:00:00
# lower_name                      pennsylvania
# state                           pennsylvania
# pop_2020                               44500
# pop_2018                               45941
# capacity                               48961
# pct_occup                           0.938318
# Name: 436, dtype: object
# name                            Pennsylvania
# total_staff_cases                         90
# total_prisoner_cases                      47
# total_staff_deaths                         0
# total_prisoner_deaths                      3
# as_of_date               2020-04-29 00:00:00
# lower_name                      pennsylvania
# state                           pennsylvania
# pop_2020                               44500
# pop_2018                               45941
# capacity                               48961
# pct_occup                           0.938318
# Name: 437, dtype: object
# name                            Pennsylvania
# total_staff_cases                        127
# total_prisoner_cases                     143
# total_staff_deaths                         0
# total_prisoner_deaths                      3
# as_of_date               2020-05-06 00:00:00
# lower_name                      pennsylvania
# state                           pennsylvania
# pop_2020                               44500
# pop_2018                               45941
# capacity                               48961
# pct_occup                           0.938318
# Name: 438, dtype: object
# name                            Pennsylvania
# total_staff_cases                        148
# total_prisoner_cases                     214
# total_staff_deaths                         0
# total_prisoner_deaths                      3
# as_of_date               2020-05-13 00:00:00
# lower_name                      pennsylvania
# state                           pennsylvania
# pop_2020                               44500
# pop_2018                               45941
# capacity                               48961
# pct_occup                           0.938318
# Name: 439, dtype: object
# name                            Pennsylvania
# total_staff_cases                        160
# total_prisoner_cases                     227
# total_staff_deaths                         1
# total_prisoner_deaths                      5
# as_of_date               2020-05-20 00:00:00
# lower_name                      pennsylvania
# state                           pennsylvania
# pop_2020                               44500
# pop_2018                               45941
# capacity                               48961
# pct_occup                           0.938318
# Name: 440, dtype: object
# name                                 Florida
# total_staff_cases                          7
# total_prisoner_cases                       0
# total_staff_deaths                         0
# total_prisoner_deaths                      0
# as_of_date               2020-03-27 00:00:00
# lower_name                           florida
# state                                florida
# pop_2020                               85169
# pop_2018                               85169
# capacity                               87103
# pct_occup                           0.977796
# Name: 441, dtype: object
# name                                 Florida
# total_staff_cases                         12
# total_prisoner_cases                       0
# total_staff_deaths                         0
# total_prisoner_deaths                      0
# as_of_date               2020-04-01 00:00:00
# lower_name                           florida
# state                                florida
# pop_2020                               85169
# pop_2018                               85169
# capacity                               87103
# pct_occup                           0.977796
# Name: 442, dtype: object
# name                                 Florida
# total_staff_cases                         40
# total_prisoner_cases                       5
# total_staff_deaths                         0
# total_prisoner_deaths                      0
# as_of_date               2020-04-08 00:00:00
# lower_name                           florida
# state                                florida
# pop_2020                               85169
# pop_2018                               85169
# capacity                               87103
# pct_occup                           0.977796
# Name: 443, dtype: object
# name                                 Florida
# total_staff_cases                         58
# total_prisoner_cases                      42
# total_staff_deaths                         0
# total_prisoner_deaths                      2
# as_of_date               2020-04-15 00:00:00
# lower_name                           florida
# state                                florida
# pop_2020                               85169
# pop_2018                               85169
# capacity                               87103
# pct_occup                           0.977796
# Name: 444, dtype: object
# name                                 Florida
# total_staff_cases                        102
# total_prisoner_cases                     136
# total_staff_deaths                         0
# total_prisoner_deaths                      4
# as_of_date               2020-04-22 00:00:00
# lower_name                           florida
# state                                florida
# pop_2020                               85169
# pop_2018                               85169
# capacity                               87103
# pct_occup                           0.977796
# Name: 445, dtype: object
# name                                 Florida
# total_staff_cases                        143
# total_prisoner_cases                     202
# total_staff_deaths                         0
# total_prisoner_deaths                      5
# as_of_date               2020-04-29 00:00:00
# lower_name                           florida
# state                                florida
# pop_2020                               85169
# pop_2018                               85169
# capacity                               87103
# pct_occup                           0.977796
# Name: 446, dtype: object
# name                                 Florida
# total_staff_cases                        180
# total_prisoner_cases                     393
# total_staff_deaths                         0
# total_prisoner_deaths                      7
# as_of_date               2020-05-06 00:00:00
# lower_name                           florida
# state                                florida
# pop_2020                               85169
# pop_2018                               85169
# capacity                               87103
# pct_occup                           0.977796
# Name: 447, dtype: object
# name                                 Florida
# total_staff_cases                        208
# total_prisoner_cases                     843
# total_staff_deaths                         0
# total_prisoner_deaths                      9
# as_of_date               2020-05-13 00:00:00
# lower_name                           florida
# state                                florida
# pop_2020                               85169
# pop_2018                               85169
# capacity                               87103
# pct_occup                           0.977796
# Name: 448, dtype: object
# name                                 Florida
# total_staff_cases                        241
# total_prisoner_cases                    1191
# total_staff_deaths                         0
# total_prisoner_deaths                     10
# as_of_date               2020-05-20 00:00:00
# lower_name                           florida
# state                                florida
# pop_2020                               85169
# pop_2018                               85169
# capacity                               87103
# pct_occup                           0.977796
# Name: 449, dtype: object
# name                             Connecticut
# total_staff_cases                          3
# total_prisoner_cases                       2
# total_staff_deaths                         0
# total_prisoner_deaths                      0
# as_of_date               2020-03-27 00:00:00
# lower_name                       connecticut
# state                            connecticut
# pop_2020                               13228
# pop_2018                               13228
# capacity                               13228
# pct_occup                                  1
# Name: 450, dtype: object
# name                             Connecticut
# total_staff_cases                          3
# total_prisoner_cases                       2
# total_staff_deaths                         0
# total_prisoner_deaths                      0
# as_of_date               2020-04-01 00:00:00
# lower_name                       connecticut
# state                            connecticut
# pop_2020                               13228
# pop_2018                               13228
# capacity                               13228
# pct_occup                                  1
# Name: 451, dtype: object
# name                             Connecticut
# total_staff_cases                         52
# total_prisoner_cases                      46
# total_staff_deaths                         0
# total_prisoner_deaths                      0
# as_of_date               2020-04-07 00:00:00
# lower_name                       connecticut
# state                            connecticut
# pop_2020                               13228
# pop_2018                               13228
# capacity                               13228
# pct_occup                                  1
# Name: 452, dtype: object
# name                             Connecticut
# total_staff_cases                        139
# total_prisoner_cases                     199
# total_staff_deaths                         0
# total_prisoner_deaths                      1
# as_of_date               2020-04-15 00:00:00
# lower_name                       connecticut
# state                            connecticut
# pop_2020                               13228
# pop_2018                               13228
# capacity                               13228
# pct_occup                                  1
# Name: 453, dtype: object
# name                             Connecticut
# total_staff_cases                        244
# total_prisoner_cases                     321
# total_staff_deaths                         0
# total_prisoner_deaths                      1
# as_of_date               2020-04-22 00:00:00
# lower_name                       connecticut
# state                            connecticut
# pop_2020                               13228
# pop_2018                               13228
# capacity                               13228
# pct_occup                                  1
# Name: 454, dtype: object
# name                             Connecticut
# total_staff_cases                        326
# total_prisoner_cases                     417
# total_staff_deaths                         0
# total_prisoner_deaths                      3
# as_of_date               2020-04-29 00:00:00
# lower_name                       connecticut
# state                            connecticut
# pop_2020                               13228
# pop_2018                               13228
# capacity                               13228
# pct_occup                                  1
# Name: 455, dtype: object
# name                             Connecticut
# total_staff_cases                        358
# total_prisoner_cases                     478
# total_staff_deaths                         0
# total_prisoner_deaths                      6
# as_of_date               2020-05-06 00:00:00
# lower_name                       connecticut
# state                            connecticut
# pop_2020                               13228
# pop_2018                               13228
# capacity                               13228
# pct_occup                                  1
# Name: 456, dtype: object
# name                             Connecticut
# total_staff_cases                        368
# total_prisoner_cases                     526
# total_staff_deaths                         0
# total_prisoner_deaths                      6
# as_of_date               2020-05-13 00:00:00
# lower_name                       connecticut
# state                            connecticut
# pop_2020                               13228
# pop_2018                               13228
# capacity                               13228
# pct_occup                                  1
# Name: 457, dtype: object
# name                             Connecticut
# total_staff_cases                        373
# total_prisoner_cases                     684
# total_staff_deaths                         0
# total_prisoner_deaths                      6
# as_of_date               2020-05-20 00:00:00
# lower_name                       connecticut
# state                            connecticut
# pop_2020                               13228
# pop_2018                               13228
# capacity                               13228
# pct_occup                                  1
# Name: 458, dtype: object

# %%
marshall['lower_name'] = marshall['name'].str.lower()

demographics = ['state', 'pop_2020', 'pop_2018', 'capacity', 'pct_occup']
policies = ['state', 'effective_date', 'no_visits', 'lawyer_access', 'phone_access', 'video_access', 'no_volunteers', 'limiting_movement', 'screening', 'healthcare_support']

# %%
df.columns
# Out:
# Index(['state', 'pop_2020', 'pop_2018', 'capacity', 'pct_occup',
#        'effective_date', 'no_visits', 'lawyer_access', 'phone_access',
#        'video_access', 'no_volunteers', 'limiting_movement', 'screening',
#        'healthcare_support'],
#       dtype='object')

# %%
df
# Out:
#              state  pop_2020  pop_2018  capacity  pct_occup effective_date  \
# 0       california  114000.0  117937.0  122302.0   0.964310     2020-03-14
# 1         colorado   20000.0   16086.0   14738.0   1.091464     2020-03-11
# 2          federal  174000.0       NaN       NaN        NaN     2020-03-13
 marshall.merge(df[['state', 'pop_2020', 'pop_2018', 'capacity', 'pct_occup']], left_on='lower_name', right_on='state')
# Out:
#             name  total_staff_cases  total_prisoner_cases  total_staff_deaths  \
# 0       Delaware                  0                     0                   0
# 1       Delaware                  0                     0                   0
# 2       Delaware                  6                     2                   0
# 3       Delaware                 18                    13                   0
# 4       Delaware                 26                    41                   0
# ..           ...                ...                   ...                 ...
# 445  Connecticut                244                   321                   0
# 446  Connecticut                326                   417                   0
# 447  Connecticut                358                   478                   0
# 448  Connecticut                368                   526                   0
# 449  Connecticut                373                   684                   0
#
#      total_prisoner_deaths as_of_date   lower_name        state  pop_2020  \
# 0                        0 2020-03-24     delaware     delaware    5582.0
# 1                        0 2020-04-01     delaware     delaware    5582.0
# 2                        0 2020-04-08     delaware     delaware    5582.0
# 3                        0 2020-04-15     delaware     delaware    5582.0
# 4                        1 2020-04-22     delaware     delaware    5582.0
# ..                     ...        ...          ...          ...       ...
# 445                      1 2020-04-22  connecticut  connecticut   13228.0
# 446                      3 2020-04-29  connecticut  connecticut   13228.0
# 447                      6 2020-05-06  connecticut  connecticut   13228.0
# 448                      6 2020-05-13  connecticut  connecticut   13228.0
# 449                      6 2020-05-20  connecticut  connecticut   13228.0
#
#      pop_2018  capacity  pct_occup
# 0      5582.0    5566.0   1.002875
# 1      5582.0    5566.0   1.002875
# 2      5582.0    5566.0   1.002875
# 3      5582.0    5566.0   1.002875
# 4      5582.0    5566.0   1.002875
# ..        ...       ...        ...
# 445   13228.0   13228.0   1.000000
# 446   13228.0   13228.0   1.000000
# 447   13228.0   13228.0   1.000000
# 448   13228.0   13228.0   1.000000
# 449   13228.0   13228.0   1.000000
#
# [450 rows x 12 columns]

# %%
pd.options.display.max_columns = None

marshall
# Out:
#               name  total_staff_cases  total_prisoner_cases  \
# 415       Delaware                  0                     0
# 420       Illinois                  3                     3
# 458        Federal                  8                    10
# 430      Minnesota                  0                     0
# 429       Michigan                 25                    24
# ..             ...                ...                   ...
# 34            Ohio                622                  4550
# 26        Nebraska                 10                     7
# 36          Oregon                 38                   143
# 20   Massachusetts                165                   375
# 1           Alaska                 11                     2
#
#      total_staff_deaths  total_prisoner_deaths as_of_date     lower_name
# 415                   0                      0 2020-03-24       delaware
# 420                   0                      0 2020-03-25       illinois
# 458                   0                      0 2020-03-26        federal
# 430                   0                      0 2020-03-26      minnesota
# 429                   0                      0 2020-03-26       michigan
# ..                  ...                    ...        ...            ...
# 34                    4                     63 2020-05-20           ohio
# 26                    0                      0 2020-05-20       nebraska
# 36                    0                      1 2020-05-21         oregon
# 20                    0                      8 2020-05-21  massachusetts
# 1                     0                      0 2020-05-21         alaska
#
# [459 rows x 7 columns]

# %%
marshall.columns
# Out:
# Index(['name', 'total_staff_cases', 'total_prisoner_cases',
#        'total_staff_deaths', 'total_prisoner_deaths', 'as_of_date',
#        'lower_name'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['state', 'pop_2020', 'pop_2018', 'capacity', 'pct_occup',
#        'effective_date', 'no_visits', 'lawyer_access', 'phone_access',
#        'video_access', 'no_volunteers', 'limiting_movement', 'screening',
#        'healthcare_support'],
#       dtype='object')
